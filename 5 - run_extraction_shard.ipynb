# %% [markdown]
# # Radiomics re-extraction (5-notebook parallel runner)
#
# Duplicate this notebook **5 times**. In each copy, edit only the **shard cell** below
# (uncomment your shard index). Run order:
#
# 1. Run the **smoke test** once, in a single notebook, to confirm the pipeline.
# 2. Run **Step 1 (normalize)** in all 5 notebooks. Wait until all 5 finish.
# 3. Run **Step 2 (extract)** in all 5 notebooks. Wait until all 5 finish.
# 4. Run **Step 3 (combine)** once, in a single notebook.
#
# A notebook that times out can simply be rerun: finished cases are skipped.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Same environment your !python calls will use
# !pip install SimpleITK -q
# !pip install git+https://github.com/AIM-Harvard/pyradiomics@v3.1.0 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 14.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 7.2 MB/s eta 0:00:00
#   Building wheel for pyradiomics (pyproject.toml) ... done
#   Building wheel for docopt (setup.py) ... done

# %% [markdown]
# ## Shard cell  ← the ONLY thing you change per duplicated notebook
#
# Leave `NUM_SHARDS = 5`. Uncomment exactly one `SHARD_INDEX` line.

# %%
# --- Path to the folder where you pasted the three .py scripts ---
SCRIPT_DIR = '/content/drive/MyDrive/bsd/11_radiomics_for_gliomas/02_train/trial_80/notebooks'

# --- This notebook's shard. Uncomment exactly ONE line. ---
NUM_SHARDS = 5
# SHARD_INDEX = 0
# SHARD_INDEX = 1
# SHARD_INDEX = 2
# SHARD_INDEX = 3
SHARD_INDEX = 4

import os
NORMALIZE_SCRIPT = os.path.join(SCRIPT_DIR, '04_normalize_images.py')
EXTRACT_SCRIPT   = os.path.join(SCRIPT_DIR, '05_extract_wt_radiomics.py')
COMBINE_SCRIPT   = os.path.join(SCRIPT_DIR, '06_combine_features.py')

print(f"This notebook = shard {SHARD_INDEX} of {NUM_SHARDS}")
print(f"Scripts found:",
      os.path.exists(NORMALIZE_SCRIPT),
      os.path.exists(EXTRACT_SCRIPT),
      os.path.exists(COMBINE_SCRIPT))
# Out:
# This notebook = shard 4 of 5
# Scripts found: True True True

# %% [markdown]
# ## Smoke test (run ONCE, in a single notebook)
#
# No shard arguments = single-case test on BT0791. Normalizes that one case, then
# extracts it and prints the feature count. Confirms there is no GLCM hang before
# you commit all 5 machines.

# %%
# !python "{NORMALIZE_SCRIPT}"
# !python "{EXTRACT_SCRIPT}"
# Out:
# SMOKE TEST MODE: normalizing only BT0791
#
# Normalizing: BT0791
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Smoke test done.
# Fixed bin Count enabled! However, we recommend using a fixed bin Width. See http://pyradiomics.readthedocs.io/en/latest/faq.html#radiomics-fixed-bin-width for more details
# Extractor settings:
# {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binCount': 64}
#
# SMOKE TEST MODE: extracting only BT0791, nothing will be written.
#
# Extracting features for: BT0791
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> SMOKE TEST: 4224 features extracted (no hang).
#   -> sample keys: ['FLAIR_original_firstorder_10Percentile', 'FLAIR_original_firstorder_90Percentile', 'FLAIR_original_firstorder_Energy', 'FLAIR_original_firstorder_Entropy', 'FLAIR_original_firstorder_InterquartileRange']
#
# Smoke test done.

# %% [markdown]
# ## Step 1: Normalize (run in ALL 5 notebooks)
#
# Each notebook normalizes its own one-fifth of the cases. Wait for all 5 to finish
# before Step 2, because extraction reads the `_norm` files produced here.

# %%
# !python "{NORMALIZE_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Shard 4 of 5. Total case folders: 2061
#
# Normalizing: BT0007
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0015
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0023
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0030
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0041
#   -> flair: brain mean 606.77, std 140.24 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1410.61, std 265.12 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1465.98, std 227.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 993.59, std 285.40 -> saved t2_norm.nii.gz
#
# Normalizing: BT0053
#   -> flair: brain mean 147.20, std 47.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 763.10, std 155.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 460.64, std 109.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 647.70, std 264.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT0062
#   -> flair: brain mean 444.57, std 102.15 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 422.00, std 72.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 464.72, std 81.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 555.66, std 238.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT0070
#   -> flair: brain mean 4707.44, std 976.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6410.13, std 1545.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 5080.76, std 1255.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 3927.83, std 920.14 -> saved t2_norm.nii.gz
#
# Normalizing: BT0081
#   -> flair: brain mean 417.93, std 101.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 849.60, std 166.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 861.70, std 176.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 473.09, std 150.61 -> saved t2_norm.nii.gz
#
# Normalizing: BT0089
#   -> flair: brain mean 268.52, std 66.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1343.56, std 185.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1488.24, std 228.58 -> saved t1_norm.nii.gz
#   -> t2: brain mean 339.85, std 150.15 -> saved t2_norm.nii.gz
#
# Normalizing: BT0099
#   -> flair: brain mean 383.22, std 104.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 475.24, std 113.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 699.03, std 121.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 636.15, std 250.54 -> saved t2_norm.nii.gz
#
# Normalizing: BT0107
#   -> flair: brain mean 428.93, std 178.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 614.64, std 293.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 539.04, std 251.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1168.73, std 412.69 -> saved t2_norm.nii.gz
#
# Normalizing: BT0119
#   -> flair: brain mean 414.74, std 81.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 666.92, std 135.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 725.46, std 174.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 678.16, std 175.22 -> saved t2_norm.nii.gz
#
# Normalizing: BT0127
#   -> flair: brain mean 1598.16, std 328.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2454.13, std 469.04 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 8166.90, std 2276.63 -> saved t1_norm.nii.gz
#   -> t2: brain mean 796.52, std 181.41 -> saved t2_norm.nii.gz
#
# Normalizing: BT0136
#   -> flair: brain mean 196.98, std 37.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 587.80, std 126.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 596.10, std 126.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 523.74, std 140.57 -> saved t2_norm.nii.gz
#
# Normalizing: BT0141
#   -> flair: brain mean 298.76, std 73.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 513.44, std 96.18 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 986.88, std 149.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 454.76, std 232.27 -> saved t2_norm.nii.gz
#
# Normalizing: BT0146
#   -> flair: brain mean 438.98, std 113.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1075.38, std 207.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1248.06, std 180.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 573.06, std 256.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT0152
#   -> flair: brain mean 155.04, std 46.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 477.55, std 88.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 452.13, std 70.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 331.19, std 104.41 -> saved t2_norm.nii.gz
#
# Normalizing: BT0159
#   -> flair: brain mean 348.60, std 70.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 791.53, std 117.55 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 864.11, std 143.67 -> saved t1_norm.nii.gz
#   -> t2: brain mean 450.79, std 161.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT0168
#   -> flair: brain mean 552.72, std 138.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1520.85, std 206.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1632.19, std 254.82 -> saved t1_norm.nii.gz
#   -> t2: brain mean 881.76, std 393.18 -> saved t2_norm.nii.gz
#
# Normalizing: BT0179
#   -> flair: brain mean 22152.43, std 5757.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 26559.29, std 7467.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 25251.29, std 8433.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 46784.41, std 25578.50 -> saved t2_norm.nii.gz
#
# Normalizing: BT0187
#   -> flair: brain mean 636.14, std 130.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 12917.65, std 3093.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 620.41, std 147.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 177.70, std 49.79 -> saved t2_norm.nii.gz
#
# Normalizing: BT0193
#   -> flair: brain mean 287.78, std 62.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 539.16, std 72.30 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 496.37, std 72.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 318.11, std 105.25 -> saved t2_norm.nii.gz
#
# Normalizing: BT0204
#   -> flair: brain mean 138.96, std 23.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 386.25, std 53.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 509.85, std 84.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 257.97, std 71.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT0212
#   -> flair: brain mean 351.79, std 73.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 586.90, std 100.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 658.49, std 108.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 488.72, std 171.00 -> saved t2_norm.nii.gz
#
# Normalizing: BT0221
#   -> flair: brain mean 454.76, std 106.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1101.14, std 168.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1637.16, std 232.86 -> saved t1_norm.nii.gz
#   -> t2: brain mean 448.52, std 186.01 -> saved t2_norm.nii.gz
#
# Normalizing: BT0226
#   -> flair: brain mean 779.02, std 160.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1736.51, std 241.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1204.02, std 190.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1387.01, std 367.66 -> saved t2_norm.nii.gz
#
# Normalizing: BT0235
#   -> flair: brain mean 274.47, std 66.27 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1057.57, std 170.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 817.48, std 151.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 362.05, std 134.00 -> saved t2_norm.nii.gz
#
# Normalizing: BT0243
#   -> flair: brain mean 244.53, std 56.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 460.21, std 72.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 664.36, std 107.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 306.24, std 117.65 -> saved t2_norm.nii.gz
#
# Normalizing: BT0251
#   -> flair: brain mean 1143.44, std 285.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1159.09, std 205.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 842.90, std 156.35 -> saved t1_norm.nii.gz
#   -> t2: brain mean 841.08, std 259.23 -> saved t2_norm.nii.gz
#
# Normalizing: BT0261
#   -> flair: brain mean 493.47, std 108.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 576.88, std 79.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 571.65, std 92.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 587.55, std 198.66 -> saved t2_norm.nii.gz
#
# Normalizing: BT0273
#   -> flair: brain mean 607.20, std 119.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1339.88, std 293.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 792.63, std 156.81 -> saved t1_norm.nii.gz
#   -> t2: brain mean 842.71, std 158.50 -> saved t2_norm.nii.gz
#
# Normalizing: BT0281
#   -> flair: brain mean 322.75, std 81.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1141.95, std 191.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 852.82, std 155.58 -> saved t1_norm.nii.gz
#   -> t2: brain mean 473.01, std 139.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT0288
#   -> flair: brain mean 109.49, std 34.61 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 394.40, std 74.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 366.49, std 67.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 279.62, std 52.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT0295
#   -> flair: brain mean 524.32, std 98.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5977.11, std 1770.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1439.53, std 338.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 632.39, std 125.81 -> saved t2_norm.nii.gz
#
# Normalizing: BT0305
#   -> flair: brain mean 932.18, std 231.52 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 20117.54, std 6860.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1414.84, std 364.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 700.21, std 173.92 -> saved t2_norm.nii.gz
#
# Normalizing: BT0311
#   -> flair: brain mean 508.45, std 140.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 539.81, std 129.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 609.42, std 162.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 952.70, std 296.96 -> saved t2_norm.nii.gz
#
# Normalizing: BT0320
#   -> flair: brain mean 783.70, std 206.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1364.25, std 275.89 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 953.75, std 169.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 930.05, std 271.14 -> saved t2_norm.nii.gz
#
# Normalizing: BT0330
#   -> flair: brain mean 367.50, std 98.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1142.79, std 151.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 843.76, std 150.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 505.71, std 200.75 -> saved t2_norm.nii.gz
#
# Normalizing: BT0342
#   -> flair: brain mean 8977.33, std 2387.54 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 16791.69, std 4736.50 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 14537.70, std 4847.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 21460.66, std 4912.24 -> saved t2_norm.nii.gz
#
# Normalizing: BT0358
#   -> flair: brain mean 556.85, std 171.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1317.90, std 223.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1216.78, std 228.37 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1077.79, std 478.63 -> saved t2_norm.nii.gz
#
# Normalizing: BT0364
#   -> flair: brain mean 680.69, std 176.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1288.97, std 190.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1237.31, std 202.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1564.28, std 556.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT0374
#   -> flair: brain mean 250.97, std 45.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 310.57, std 56.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 297.13, std 58.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 295.86, std 62.60 -> saved t2_norm.nii.gz
#
# Normalizing: BT0385
#   -> flair: brain mean 386.90, std 115.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 510.99, std 114.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 493.22, std 116.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 173.92, std 58.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT0399
#   -> flair: brain mean 7072.70, std 1851.88 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6503.82, std 1156.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 7176.71, std 1355.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 4267.19, std 1964.11 -> saved t2_norm.nii.gz
#
# Normalizing: BT0408
#   -> flair: brain mean 204.91, std 84.46 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 787.34, std 169.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 730.18, std 126.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 522.06, std 362.63 -> saved t2_norm.nii.gz
#
# Normalizing: BT0421
#   -> flair: brain mean 1063.79, std 271.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 779.57, std 153.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 937.81, std 199.81 -> saved t1_norm.nii.gz
#   -> t2: brain mean 890.44, std 292.11 -> saved t2_norm.nii.gz
#
# Normalizing: BT0427
#   -> flair: brain mean 273.95, std 52.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 398.55, std 57.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 535.07, std 77.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 318.57, std 123.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0444
#   -> flair: brain mean 355.66, std 86.66 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 547.97, std 99.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 507.78, std 93.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 494.48, std 133.19 -> saved t2_norm.nii.gz
#
# Normalizing: BT0460
#   -> flair: brain mean 362.14, std 76.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 633.45, std 83.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 659.48, std 99.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 428.56, std 155.46 -> saved t2_norm.nii.gz
#
# Normalizing: BT0466
#   -> flair: brain mean 219.50, std 59.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 917.45, std 111.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1264.70, std 182.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 466.22, std 220.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0476
#   -> flair: brain mean 173.31, std 51.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 940.78, std 136.56 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 918.16, std 139.81 -> saved t1_norm.nii.gz
#   -> t2: brain mean 320.80, std 145.94 -> saved t2_norm.nii.gz
#
# Normalizing: BT0488
#   -> flair: brain mean 233.85, std 60.70 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 428.61, std 92.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 588.62, std 113.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 361.86, std 156.31 -> saved t2_norm.nii.gz
#
# Normalizing: BT0501
#   -> flair: brain mean 483.99, std 132.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1517.49, std 257.87 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1466.85, std 284.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 915.86, std 255.03 -> saved t2_norm.nii.gz
#
# Normalizing: BT0525
#   -> flair: brain mean 182.06, std 45.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 488.58, std 86.01 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 636.67, std 95.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 335.72, std 127.24 -> saved t2_norm.nii.gz
#
# Normalizing: BT0602
#   -> flair: brain mean 456.67, std 114.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 470.18, std 80.79 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 473.50, std 81.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 307.43, std 125.81 -> saved t2_norm.nii.gz
#
# Normalizing: BT0611
#   -> flair: brain mean 294.24, std 74.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 476.25, std 107.01 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 424.10, std 109.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 511.23, std 194.85 -> saved t2_norm.nii.gz
#
# Normalizing: BT0618
#   -> flair: brain mean 4742.59, std 1091.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 17935.89, std 4621.60 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 16816.17, std 4160.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2781.39, std 691.75 -> saved t2_norm.nii.gz
#
# Normalizing: BT0624
#   -> flair: brain mean 118.12, std 37.95 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 265.95, std 84.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 726.08, std 142.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 251.10, std 94.73 -> saved t2_norm.nii.gz
#
# Normalizing: BT0631
#   -> flair: brain mean 236.56, std 65.77 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 382.82, std 67.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 488.66, std 82.92 -> saved t1_norm.nii.gz
#   -> t2: brain mean 355.16, std 151.55 -> saved t2_norm.nii.gz
#
# Normalizing: BT0637
#   -> flair: brain mean 349.46, std 94.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 610.00, std 109.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 841.75, std 141.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 488.73, std 167.83 -> saved t2_norm.nii.gz
#
# Normalizing: BT0645
#   -> flair: brain mean 711.96, std 153.54 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4494.21, std 846.50 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2255.89, std 347.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2223.88, std 619.54 -> saved t2_norm.nii.gz
#
# Normalizing: BT0653
#   -> flair: brain mean 162.66, std 38.51 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 345.36, std 56.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 338.99, std 58.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 330.01, std 131.58 -> saved t2_norm.nii.gz
#
# Normalizing: BT0661
#   -> flair: brain mean 381.97, std 100.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 863.51, std 144.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1297.17, std 200.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 509.14, std 210.41 -> saved t2_norm.nii.gz
#
# Normalizing: BT0671
#   -> flair: brain mean 292.25, std 80.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 730.59, std 206.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 677.62, std 195.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 511.58, std 225.47 -> saved t2_norm.nii.gz
#
# Normalizing: BT0679
#   -> flair: brain mean 641.86, std 123.39 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 380.99, std 58.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 444.75, std 65.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 392.50, std 134.30 -> saved t2_norm.nii.gz
#
# Normalizing: BT0688
#   -> flair: brain mean 361.85, std 81.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1281.27, std 203.53 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1349.79, std 201.20 -> saved t1_norm.nii.gz
#   -> t2: brain mean 570.13, std 295.90 -> saved t2_norm.nii.gz
#
# Normalizing: BT0697
#   -> flair: brain mean 211.87, std 51.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 442.30, std 73.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 494.45, std 80.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 420.20, std 74.24 -> saved t2_norm.nii.gz
#
# Normalizing: BT0712
#   -> flair: brain mean 274.94, std 50.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 841.26, std 140.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 800.13, std 162.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 427.59, std 165.15 -> saved t2_norm.nii.gz
#
# Normalizing: BT0721
#   -> flair: brain mean 257.24, std 105.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 572.08, std 113.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 510.62, std 112.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 509.41, std 231.53 -> saved t2_norm.nii.gz
#
# Normalizing: BT0729
#   -> flair: brain mean 200.31, std 70.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 438.59, std 94.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 392.76, std 77.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 321.36, std 151.97 -> saved t2_norm.nii.gz
#
# Normalizing: BT0737
#   -> flair: brain mean 244.31, std 70.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 807.79, std 133.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 779.55, std 107.31 -> saved t1_norm.nii.gz
#   -> t2: brain mean 639.41, std 199.10 -> saved t2_norm.nii.gz
#
# Normalizing: BT0743
#   -> flair: brain mean 256.56, std 60.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 566.64, std 92.18 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 598.77, std 89.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 373.26, std 116.55 -> saved t2_norm.nii.gz
#
# Normalizing: BT0751
#   -> flair: brain mean 207.47, std 53.15 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 409.24, std 88.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 657.06, std 156.83 -> saved t1_norm.nii.gz
#   -> t2: brain mean 519.90, std 214.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT0757
#   -> flair: brain mean 490.73, std 121.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1231.94, std 253.75 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 871.17, std 196.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 880.81, std 358.75 -> saved t2_norm.nii.gz
#
# Normalizing: BT0766
#   -> flair: brain mean 520.86, std 140.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 911.31, std 208.59 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1013.04, std 181.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1038.28, std 250.86 -> saved t2_norm.nii.gz
#
# Normalizing: BT0772
#   -> flair: brain mean 645.90, std 153.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1177.96, std 339.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 476.38, std 148.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 766.81, std 208.28 -> saved t2_norm.nii.gz
#
# Normalizing: BT0783
#   -> flair: brain mean 182.73, std 66.33 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 284.98, std 109.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 690.07, std 107.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 456.88, std 223.01 -> saved t2_norm.nii.gz
#
# Normalizing: BT0788
#   -> flair: brain mean 229.91, std 70.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 509.24, std 133.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1088.73, std 184.11 -> saved t1_norm.nii.gz
#   -> t2: brain mean 730.61, std 248.36 -> saved t2_norm.nii.gz
#
# Normalizing: BT0796
#   -> flair: brain mean 523.83, std 98.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 676.48, std 101.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 637.30, std 114.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 934.31, std 303.76 -> saved t2_norm.nii.gz
#
# Normalizing: BT0807
#   -> flair: brain mean 276.01, std 84.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 573.08, std 167.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 845.27, std 156.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 501.83, std 162.28 -> saved t2_norm.nii.gz
#
# Normalizing: BT0818
#   -> flair: brain mean 582.79, std 122.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 970.08, std 217.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 915.53, std 184.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2070.23, std 716.24 -> saved t2_norm.nii.gz
#
# Normalizing: BT0830
#   -> flair: brain mean 460.16, std 102.11 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 704.01, std 181.04 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 742.95, std 187.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 746.18, std 214.37 -> saved t2_norm.nii.gz
#
# Normalizing: BT0840
#   -> flair: brain mean 233.63, std 61.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 708.85, std 109.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 596.03, std 104.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 545.92, std 200.03 -> saved t2_norm.nii.gz
#
# Normalizing: BT0848
#   -> flair: brain mean 129.26, std 25.81 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 400.35, std 83.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 361.10, std 89.98 -> saved t1_norm.nii.gz
#   -> t2: brain mean 158.35, std 125.23 -> saved t2_norm.nii.gz
#
# Normalizing: BT0908
#   -> flair: brain mean 270.54, std 66.95 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 556.80, std 214.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 659.45, std 179.40 -> saved t1_norm.nii.gz
#   -> t2: brain mean 551.33, std 229.82 -> saved t2_norm.nii.gz
#
# Normalizing: BT0919
#   -> flair: brain mean 27601.92, std 8022.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 315384.41, std 159271.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 65733.59, std 25879.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 55154.76, std 16129.35 -> saved t2_norm.nii.gz
#
# Normalizing: BT0930
#   -> flair: brain mean 360.85, std 69.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 539.40, std 82.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 544.89, std 79.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 456.13, std 155.23 -> saved t2_norm.nii.gz
#
# Normalizing: BT0947
#   -> flair: brain mean 1040.60, std 279.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 698.63, std 290.87 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1458.55, std 429.99 -> saved t1_norm.nii.gz
#   -> t2: brain mean 756.10, std 254.32 -> saved t2_norm.nii.gz
#
# Normalizing: BT0955
#   -> flair: brain mean 883.04, std 182.98 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 834.29, std 83.93 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1132.66, std 120.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 716.40, std 223.77 -> saved t2_norm.nii.gz
#
# Normalizing: BT0961
#   -> flair: brain mean 230.08, std 51.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 557.52, std 83.93 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 515.40, std 88.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 253.57, std 165.00 -> saved t2_norm.nii.gz
#
# Normalizing: BT0970
#   -> flair: brain mean 559.07, std 141.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1063.03, std 189.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 872.66, std 147.63 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1462.03, std 560.71 -> saved t2_norm.nii.gz
#
# Normalizing: BT1006
#   -> flair: brain mean 1164.51, std 250.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 830.84, std 200.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 907.59, std 165.52 -> saved t1_norm.nii.gz
#   -> t2: brain mean 874.30, std 327.52 -> saved t2_norm.nii.gz
#
# Normalizing: BT1015
#   -> flair: brain mean 728.78, std 160.85 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1984.61, std 297.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1885.42, std 346.11 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1394.94, std 411.25 -> saved t2_norm.nii.gz
#
# Normalizing: BT1020
#   -> flair: brain mean 433.98, std 94.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1309.17, std 380.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 956.98, std 165.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 569.28, std 303.45 -> saved t2_norm.nii.gz
#
# Normalizing: BT1027
#   -> flair: brain mean 1223155.62, std 361650.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 45488.41, std 8332.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 47019.61, std 8306.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 33344.40, std 9530.73 -> saved t2_norm.nii.gz
#
# Normalizing: BT1034
#   -> flair: brain mean 248.64, std 77.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 581.52, std 105.06 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 518.61, std 100.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 396.43, std 168.30 -> saved t2_norm.nii.gz
#
# Normalizing: BT1039
#   -> flair: brain mean 794.51, std 246.51 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 646.57, std 135.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 862.58, std 195.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 684.97, std 236.36 -> saved t2_norm.nii.gz
#
# Normalizing: BT1050
#   -> flair: brain mean 528.95, std 102.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1032.39, std 127.44 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 955.74, std 138.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 612.71, std 191.95 -> saved t2_norm.nii.gz
#
# Normalizing: BT1058
#   -> flair: brain mean 237.00, std 88.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 253.31, std 55.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 517.88, std 87.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 309.72, std 158.34 -> saved t2_norm.nii.gz
#
# Normalizing: BT1071
#   -> flair: brain mean 142.36, std 35.52 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 220.22, std 35.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 212.00, std 37.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 169.46, std 69.32 -> saved t2_norm.nii.gz
#
# Normalizing: BT1080
#   -> flair: brain mean 250.30, std 58.92 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 385.76, std 93.18 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 328.00, std 90.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 218.10, std 139.18 -> saved t2_norm.nii.gz
#
# Normalizing: BT1085
#   -> flair: brain mean 176.54, std 30.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 390.30, std 36.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 349.56, std 38.87 -> saved t1_norm.nii.gz
#   -> t2: brain mean 209.77, std 67.27 -> saved t2_norm.nii.gz
#
# Normalizing: BT1091
#   -> flair: brain mean 249.45, std 60.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 892.18, std 179.12 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 743.34, std 164.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 661.29, std 279.86 -> saved t2_norm.nii.gz
#
# Normalizing: BT1098
#   -> flair: brain mean 744.79, std 234.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2407.65, std 724.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 823.42, std 253.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1286.20, std 732.73 -> saved t2_norm.nii.gz
#
# Normalizing: BT1104
#   -> flair: brain mean 190.18, std 60.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 542.99, std 101.52 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 452.55, std 96.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 418.82, std 179.02 -> saved t2_norm.nii.gz
#
# Normalizing: BT1109
#   -> flair: brain mean 622.33, std 178.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 613.52, std 216.12 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 632.08, std 214.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 829.05, std 297.01 -> saved t2_norm.nii.gz
#
# Normalizing: BT1115
#   -> flair: brain mean 129.61, std 39.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 322.30, std 112.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 292.09, std 112.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 256.34, std 194.78 -> saved t2_norm.nii.gz
#
# Normalizing: BT1122
#   -> flair: brain mean 1119.25, std 255.26 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 719.39, std 192.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 706.86, std 205.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1022.86, std 398.77 -> saved t2_norm.nii.gz
#
# Normalizing: BT1128
#   -> flair: brain mean 258.04, std 69.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 383.54, std 108.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 351.05, std 110.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 267.41, std 157.69 -> saved t2_norm.nii.gz
#
# Normalizing: BT1137
#   -> flair: brain mean 223.82, std 43.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 519.65, std 96.06 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 504.83, std 99.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 197.72, std 104.54 -> saved t2_norm.nii.gz
#
# Normalizing: BT1143
#   -> flair: brain mean 162.00, std 38.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 586.22, std 90.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 653.80, std 114.99 -> saved t1_norm.nii.gz
#   -> t2: brain mean 344.52, std 118.46 -> saved t2_norm.nii.gz
#
# Normalizing: BT1151
#   -> flair: brain mean 785.89, std 191.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 494.61, std 93.87 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 694.44, std 120.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 362.74, std 150.88 -> saved t2_norm.nii.gz
#
# Normalizing: BT1209
#   -> flair: brain mean 190.28, std 43.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 438.32, std 80.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 381.11, std 83.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 288.65, std 140.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT1226
#   -> flair: brain mean 659.46, std 182.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 766.81, std 111.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 961.81, std 145.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 985.36, std 267.52 -> saved t2_norm.nii.gz
#
# Normalizing: BT1234
#   -> flair: brain mean 308.58, std 93.57 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 454.29, std 87.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 339.85, std 74.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 383.25, std 183.60 -> saved t2_norm.nii.gz
#
# Normalizing: BT1243
#   -> flair: brain mean 472.88, std 97.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 453.72, std 101.94 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 450.21, std 117.98 -> saved t1_norm.nii.gz
#   -> t2: brain mean 473.37, std 182.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT1249
#   -> flair: brain mean 304.80, std 105.54 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 537.71, std 90.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 539.26, std 105.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 501.45, std 182.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT1258
#   -> flair: brain mean 115.60, std 26.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 311.65, std 82.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 290.14, std 85.11 -> saved t1_norm.nii.gz
#   -> t2: brain mean 169.14, std 134.17 -> saved t2_norm.nii.gz
#
# Normalizing: BT1268
#   -> flair: brain mean 169.91, std 51.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 381.76, std 85.18 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 306.12, std 58.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 308.27, std 120.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT1273
#   -> flair: brain mean 279.59, std 79.48 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 468.04, std 67.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1130.22, std 156.48 -> saved t1_norm.nii.gz
#   -> t2: brain mean 400.45, std 144.61 -> saved t2_norm.nii.gz
#
# Normalizing: BT1280
#   -> flair: brain mean 242.85, std 58.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 557.44, std 126.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 526.02, std 111.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 477.70, std 224.49 -> saved t2_norm.nii.gz
#
# Normalizing: BT1286
#   -> flair: brain mean 255.42, std 47.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 452.86, std 56.53 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 620.84, std 90.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 324.42, std 77.28 -> saved t2_norm.nii.gz
#
# Normalizing: BT1298
#   -> flair: brain mean 1312.31, std 338.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1037.93, std 184.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1186.37, std 255.67 -> saved t1_norm.nii.gz
#   -> t2: brain mean 763.22, std 216.29 -> saved t2_norm.nii.gz
#
# Normalizing: BT1312
#   -> flair: brain mean 324.12, std 95.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 409.28, std 130.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 409.10, std 83.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 422.73, std 191.23 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0005
#   -> flair: brain mean 246.70, std 61.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 159.70, std 25.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 356.92, std 56.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 284.09, std 101.44 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0010
#   -> flair: brain mean 124.49, std 44.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 140.90, std 30.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 128.26, std 29.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 144.40, std 49.26 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0015
#   -> flair: brain mean 268.72, std 77.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 432.88, std 75.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 440.79, std 83.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 296.30, std 112.75 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0020
#   -> flair: brain mean 1166.79, std 442.21 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1984.33, std 709.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1236.15, std 222.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2269.53, std 1361.29 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0025
#   -> flair: brain mean 223.67, std 55.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 164.56, std 39.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 517.53, std 92.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 282.45, std 99.72 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0030
#   -> flair: brain mean 666.19, std 182.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 744.17, std 183.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 833.03, std 179.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 584.73, std 128.68 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0035
#   -> flair: brain mean 639.94, std 141.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 344.16, std 81.48 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1053.80, std 176.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 765.86, std 292.77 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0040
#   -> flair: brain mean 194.78, std 48.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 149.59, std 27.71 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 521.55, std 63.85 -> saved t1_norm.nii.gz
#   -> t2: brain mean 262.22, std 95.18 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0045
#   -> flair: brain mean 570.86, std 167.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 291.12, std 95.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1115.71, std 150.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 755.00, std 409.67 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0050
#   -> flair: brain mean 222.60, std 95.12 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 85.66, std 24.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 256.30, std 58.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 283.14, std 63.88 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0055
#   -> flair: brain mean 317.69, std 67.46 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 443.76, std 77.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 509.54, std 90.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 350.80, std 129.73 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0060
#   -> flair: brain mean 621.38, std 188.93 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 712.05, std 150.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 627.81, std 155.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 856.81, std 293.17 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0065
#   -> flair: brain mean 792.12, std 322.26 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3612.30, std 1131.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3024.48, std 865.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2080.99, std 1148.29 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0070
#   -> flair: brain mean 861.11, std 254.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3190.88, std 1026.71 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2844.98, std 386.48 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2258.00, std 1044.73 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0075
#   -> flair: brain mean 964.10, std 320.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 615.54, std 270.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 923.03, std 299.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 910.49, std 351.14 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0080
#   -> flair: brain mean 1372.76, std 378.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1854.21, std 652.02 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1906.87, std 538.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1008.05, std 462.59 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0085
#   -> flair: brain mean 736.18, std 248.95 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 706.06, std 267.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 865.31, std 342.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 878.53, std 381.27 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0090
#   -> flair: brain mean 475.20, std 120.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 646.21, std 159.50 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 603.65, std 142.51 -> saved t1_norm.nii.gz
#   -> t2: brain mean 656.05, std 236.84 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0095
#   -> flair: brain mean 98.12, std 28.88 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 67.25, std 26.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 254.70, std 58.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 214.86, std 51.91 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0100
#   -> flair: brain mean 924.98, std 322.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 805.64, std 253.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 908.55, std 243.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 494.22, std 282.03 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0105
#   -> flair: brain mean 800.97, std 171.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 787.68, std 203.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 763.01, std 143.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 767.29, std 227.44 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0110
#   -> flair: brain mean 4046.70, std 1597.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4233.87, std 2036.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2919.42, std 611.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2294.88, std 1272.94 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0115
#   -> flair: brain mean 1019.52, std 370.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1501.52, std 614.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1189.08, std 223.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 751.20, std 444.35 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0120
#   -> flair: brain mean 315.27, std 95.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 415.88, std 103.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 345.66, std 97.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 514.87, std 169.60 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0125
#   -> flair: brain mean 1440.52, std 505.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1713.54, std 678.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1364.36, std 204.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2173.78, std 1041.81 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0130
#   -> flair: brain mean 872.49, std 300.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 625.74, std 177.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 572.29, std 117.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 730.15, std 304.06 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0135
#   -> flair: brain mean 1438.20, std 466.57 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2284.60, std 873.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2304.44, std 736.87 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1329.77, std 798.82 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0140
#   -> flair: brain mean 189.99, std 55.12 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 147.67, std 26.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 289.38, std 50.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 294.11, std 121.91 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0145
#   -> flair: brain mean 772.59, std 206.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 610.55, std 119.60 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 605.34, std 182.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 415.67, std 205.27 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0150
#   -> flair: brain mean 620.44, std 185.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1075.31, std 276.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1200.24, std 252.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 773.79, std 292.33 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0155
#   -> flair: brain mean 958.64, std 370.03 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1515.08, std 670.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1441.36, std 520.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1004.26, std 619.53 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0160
#   -> flair: brain mean 357.20, std 76.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 435.04, std 86.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 349.43, std 90.03 -> saved t1_norm.nii.gz
#   -> t2: brain mean 479.66, std 126.09 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0165
#   -> flair: brain mean 786.86, std 245.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 806.36, std 205.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 569.43, std 147.82 -> saved t1_norm.nii.gz
#   -> t2: brain mean 402.66, std 204.92 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0170
#   -> flair: brain mean 152.77, std 46.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 181.10, std 37.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 181.80, std 40.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 182.67, std 59.55 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0175
#   -> flair: brain mean 286.55, std 98.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 513.75, std 97.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 376.31, std 85.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 452.34, std 167.30 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0180
#   -> flair: brain mean 281.51, std 67.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 874.71, std 167.25 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 844.16, std 170.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 593.45, std 208.97 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0185
#   -> flair: brain mean 299.47, std 84.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 409.43, std 76.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 317.68, std 64.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 409.50, std 151.43 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0190
#   -> flair: brain mean 120.16, std 45.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 62.34, std 32.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 296.40, std 75.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 210.10, std 42.93 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0195
#   -> flair: brain mean 230.33, std 84.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 335.72, std 83.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 370.42, std 82.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 415.53, std 188.22 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0200
#   -> flair: brain mean 166.92, std 58.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 210.86, std 53.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 186.98, std 49.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 211.40, std 43.00 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0205
#   -> flair: brain mean 255.44, std 80.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 309.29, std 77.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 311.64, std 81.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 268.32, std 109.00 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0210
#   -> flair: brain mean 216.93, std 48.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 204.41, std 39.56 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 692.65, std 101.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 273.52, std 99.17 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0215
#   -> flair: brain mean 293.82, std 74.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 584.77, std 98.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 335.82, std 68.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 382.78, std 127.65 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0220
#   -> flair: brain mean 607.05, std 245.24 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 624.92, std 209.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 663.70, std 156.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 729.98, std 318.36 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0225
#   -> flair: brain mean 314.01, std 69.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 568.82, std 106.55 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 376.50, std 89.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 487.35, std 109.16 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0230
# ...
#
# Normalizing: UCSF-PDGM-0269_nifti
#   -> flair: brain mean 1915.73, std 542.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 7022.37, std 1827.06 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 5113.35, std 1310.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 664.62, std 253.48 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0275_nifti
#   -> flair: brain mean 990.69, std 434.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2586.02, std 875.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2174.49, std 709.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 750.65, std 475.06 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0281_nifti
#   -> flair: brain mean 1168.43, std 405.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4871.03, std 1225.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4060.68, std 1125.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1019.59, std 463.29 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0286_nifti
#   -> flair: brain mean 917.58, std 349.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3483.07, std 1108.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3048.15, std 863.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 603.77, std 259.39 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0295_nifti
#   -> flair: brain mean 1318.15, std 430.85 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4100.75, std 1241.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3069.75, std 826.81 -> saved t1_norm.nii.gz
#   -> t2: brain mean 692.64, std 278.58 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0302_nifti
#   -> flair: brain mean 1091.47, std 350.24 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3374.23, std 1239.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2676.97, std 714.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 726.96, std 293.63 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0307_nifti
#   -> flair: brain mean 671.69, std 228.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2075.87, std 656.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1821.03, std 624.23 -> saved t1_norm.nii.gz
#   -> t2: brain mean 529.29, std 267.83 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0312_nifti
#   -> flair: brain mean 729.83, std 251.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3964.25, std 1406.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2943.59, std 883.91 -> saved t1_norm.nii.gz
#   -> t2: brain mean 530.04, std 239.14 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0318_nifti
#   -> flair: brain mean 1881.11, std 671.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2834.99, std 980.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2531.74, std 736.03 -> saved t1_norm.nii.gz
#   -> t2: brain mean 548.86, std 223.05 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0324_nifti
#   -> flair: brain mean 1561.57, std 526.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2236.50, std 760.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1972.10, std 684.67 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1304.72, std 535.02 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0329_nifti
#   -> flair: brain mean 1248.45, std 451.59 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3092.86, std 846.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2873.70, std 767.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 598.08, std 316.24 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0334_nifti
#   -> flair: brain mean 1139.01, std 353.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3794.30, std 1089.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2182.64, std 417.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 650.03, std 337.45 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0339_nifti
#   -> flair: brain mean 1110.00, std 383.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3519.33, std 1142.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1519.84, std 256.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 631.34, std 378.78 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0344_nifti
#   -> flair: brain mean 795.97, std 327.66 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1144.17, std 814.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3408.49, std 812.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 710.21, std 361.48 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0349_nifti
#   -> flair: brain mean 1054.56, std 335.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6754.04, std 1700.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4735.95, std 1330.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 458.19, std 191.13 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0354_nifti
#   -> flair: brain mean 1101.46, std 343.39 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4689.26, std 1450.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4205.08, std 1041.70 -> saved t1_norm.nii.gz
#   -> t2: brain mean 405.41, std 137.11 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0359_nifti
#   -> flair: brain mean 969.17, std 358.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2436.35, std 790.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2317.95, std 669.20 -> saved t1_norm.nii.gz
#   -> t2: brain mean 677.19, std 397.35 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0364_nifti
#   -> flair: brain mean 835.89, std 319.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4179.57, std 1042.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2854.71, std 770.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 482.51, std 315.00 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0369_nifti
#   -> flair: brain mean 1161.80, std 388.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3314.87, std 973.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2720.94, std 821.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 731.22, std 407.94 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0374_nifti
#   -> flair: brain mean 1034.14, std 355.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4861.94, std 1365.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3667.26, std 1082.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 561.53, std 294.20 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0379_nifti
#   -> flair: brain mean 1152.67, std 392.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4795.66, std 1216.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2787.83, std 863.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 642.46, std 264.23 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0384_nifti
#   -> flair: brain mean 819.44, std 303.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3537.90, std 1276.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2847.10, std 958.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 450.96, std 234.91 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0389_nifti
#   -> flair: brain mean 1045.65, std 355.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2453.63, std 862.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1398.07, std 227.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 542.32, std 282.31 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0394_nifti
#   -> flair: brain mean 1139.95, std 373.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4185.24, std 1207.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3416.90, std 821.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 596.61, std 232.68 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0399_nifti
#   -> flair: brain mean 1131.01, std 406.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4460.83, std 1138.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3210.59, std 823.20 -> saved t1_norm.nii.gz
#   -> t2: brain mean 500.54, std 248.03 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0404_nifti
#   -> flair: brain mean 1297.24, std 427.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4481.19, std 1353.64 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2972.63, std 939.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 876.37, std 479.69 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0410_nifti
#   -> flair: brain mean 916.83, std 317.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3486.57, std 888.55 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3261.41, std 851.56 -> saved t1_norm.nii.gz
#   -> t2: brain mean 556.22, std 220.33 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0415_nifti
#   -> flair: brain mean 1005.05, std 324.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3509.01, std 1114.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3393.48, std 844.03 -> saved t1_norm.nii.gz
#   -> t2: brain mean 500.05, std 302.37 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0420_nifti
#   -> flair: brain mean 2488.67, std 774.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5154.62, std 1241.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4587.53, std 1229.41 -> saved t1_norm.nii.gz
#   -> t2: brain mean 969.80, std 458.97 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0425_nifti
#   -> flair: brain mean 957.82, std 321.14 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4501.10, std 1445.41 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3384.13, std 1005.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 595.68, std 279.55 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0430_nifti
#   -> flair: brain mean 816.62, std 292.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3261.72, std 1027.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2847.82, std 779.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 614.63, std 347.45 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0435_nifti
#   -> flair: brain mean 1024.08, std 398.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 247.01, std 93.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 233.74, std 76.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 492.38, std 306.51 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0440_nifti
#   -> flair: brain mean 1182.08, std 445.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4502.42, std 1356.16 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3890.98, std 1039.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 511.87, std 207.68 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0445_nifti
#   -> flair: brain mean 1423.76, std 450.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5052.16, std 1717.89 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3964.08, std 1234.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 753.62, std 415.12 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0450_nifti
#   -> flair: brain mean 1069.25, std 376.87 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4152.45, std 1228.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3121.71, std 969.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 691.12, std 391.12 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0455_nifti
#   -> flair: brain mean 936.32, std 400.61 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3461.26, std 976.60 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2778.59, std 759.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 519.47, std 259.23 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0460_nifti
#   -> flair: brain mean 1062.84, std 381.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3964.77, std 1150.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3382.64, std 938.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 661.17, std 360.89 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0465_nifti
#   -> flair: brain mean 1105.78, std 319.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4115.22, std 987.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2938.36, std 624.35 -> saved t1_norm.nii.gz
#   -> t2: brain mean 475.65, std 165.57 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0470_nifti
#   -> flair: brain mean 1183.76, std 415.95 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5627.99, std 1725.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1579.52, std 253.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 748.09, std 355.40 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0475_nifti
#   -> flair: brain mean 940.62, std 340.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5183.17, std 1454.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1950.21, std 354.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 685.35, std 318.67 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0480_nifti
#   -> flair: brain mean 319.52, std 155.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1241.97, std 366.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1240.89, std 368.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 276.81, std 209.26 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0485_nifti
#   -> flair: brain mean 1011.79, std 388.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1980.35, std 770.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1813.21, std 678.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 955.73, std 468.87 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0490_nifti
#   -> flair: brain mean 1133.36, std 382.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3031.85, std 773.41 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2650.21, std 696.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 595.72, std 243.56 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0495_nifti
#   -> flair: brain mean 723.47, std 257.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4160.33, std 1285.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3221.73, std 999.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 498.32, std 245.53 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0500_nifti
#   -> flair: brain mean 993.23, std 321.54 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3683.35, std 1015.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1476.42, std 294.79 -> saved t1_norm.nii.gz
#   -> t2: brain mean 578.07, std 376.79 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0505_nifti
#   -> flair: brain mean 624.33, std 211.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3247.31, std 978.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2923.10, std 969.82 -> saved t1_norm.nii.gz
#   -> t2: brain mean 482.39, std 231.99 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0510_nifti
#   -> flair: brain mean 1300.73, std 447.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4478.83, std 1230.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3591.86, std 802.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 631.64, std 276.72 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0515_nifti
#   -> flair: brain mean 920.59, std 346.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2884.68, std 947.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2469.15, std 717.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 733.81, std 425.65 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0520_nifti
#   -> flair: brain mean 1163.92, std 405.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3984.01, std 1228.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3311.84, std 918.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 547.51, std 262.22 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0525_nifti
#   -> flair: brain mean 921.54, std 341.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3560.40, std 1338.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2687.54, std 846.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 690.19, std 358.67 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0530_nifti
#   -> flair: brain mean 1101.83, std 402.24 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3654.40, std 1008.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2994.26, std 846.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 657.28, std 287.01 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0535_nifti
#   -> flair: brain mean 907.45, std 281.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3724.52, std 1005.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2566.49, std 666.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 568.43, std 197.74 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0540_nifti
#   -> flair: brain mean 1017.18, std 355.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2677.53, std 835.79 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2667.15, std 790.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 764.92, std 460.67 -> saved t2_norm.nii.gz
#
# Shard 4 of 5 complete.

# %% [markdown]
# ## Step 2: Extract (run in ALL 5 notebooks, after Step 1 is fully done)
#
# Each notebook extracts its own one-fifth and writes one CSV per case into
# `features/per_case/`. Safe to run concurrently (no shared file).

# %%
# !python "{EXTRACT_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Streaming output truncated to the last 5000 lines.
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote TCGA-HT-8563.csv
# Extracting features for: UCSF-PDGM-0008_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0008_nifti.csv
# Extracting features for: UCSF-PDGM-0013_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0013_nifti.csv
# Extracting features for: UCSF-PDGM-0018_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0018_nifti.csv
# Extracting features for: UCSF-PDGM-0023_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0023_nifti.csv
# Extracting features for: UCSF-PDGM-0029_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0029_nifti.csv
# Extracting features for: UCSF-PDGM-0034_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0034_nifti.csv
# Extracting features for: UCSF-PDGM-0039_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0039_nifti.csv
# Extracting features for: UCSF-PDGM-0044_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0044_nifti.csv
# Extracting features for: UCSF-PDGM-0049_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0049_nifti.csv
# Extracting features for: UCSF-PDGM-0057_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0525_nifti.csv
# Extracting features for: UCSF-PDGM-0530_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0530_nifti.csv
# Extracting features for: UCSF-PDGM-0535_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0535_nifti.csv
# Extracting features for: UCSF-PDGM-0540_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0540_nifti.csv
#
# Shard 4 of 5 complete.

# %% [markdown]
# ## Step 3: Combine (run ONCE, in a single notebook, after all of Step 2 is done)
#
# Concatenates every per-case CSV into `all_radiomics_features.csv` and prints
# per-cohort counts plus any cases missing a sequence.

# %%
# !python "{COMBINE_SCRIPT}"
