# %% [markdown]
# # Radiomics re-extraction (5-notebook parallel runner)
#
# Duplicate this notebook **5 times**. In each copy, edit only the **shard cell** below
# (uncomment your shard index). Run order:
#
# 1. Run the **smoke test** once, in a single notebook, to confirm the pipeline.
# 2. Run **Step 1 (normalize)** in all 5 notebooks. Wait until all 5 finish.
# 3. Run **Step 2 (extract)** in all 5 notebooks. Wait until all 5 finish.
# 4. Run **Step 3 (combine)** once, in a single notebook.
#
# A notebook that times out can simply be rerun: finished cases are skipped.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Same environment your !python calls will use
# !pip install SimpleITK -q
# !pip install git+https://github.com/AIM-Harvard/pyradiomics@v3.1.0 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 16.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 5.9 MB/s eta 0:00:00
#   Building wheel for pyradiomics (pyproject.toml) ... done
#   Building wheel for docopt (setup.py) ... done

# %% [markdown]
# ## Shard cell  ← the ONLY thing you change per duplicated notebook
#
# Leave `NUM_SHARDS = 5`. Uncomment exactly one `SHARD_INDEX` line.

# %%
# --- Path to the folder where you pasted the three .py scripts ---
SCRIPT_DIR = '/content/drive/MyDrive/bsd/11_radiomics_for_gliomas/02_train/trial_80/notebooks'

# --- This notebook's shard. Uncomment exactly ONE line. ---
NUM_SHARDS = 5
# SHARD_INDEX = 0
SHARD_INDEX = 1
# SHARD_INDEX = 2
# SHARD_INDEX = 3
# SHARD_INDEX = 4

import os
NORMALIZE_SCRIPT = os.path.join(SCRIPT_DIR, '04_normalize_images.py')
EXTRACT_SCRIPT   = os.path.join(SCRIPT_DIR, '05_extract_wt_radiomics.py')
COMBINE_SCRIPT   = os.path.join(SCRIPT_DIR, '06_combine_features.py')

print(f"This notebook = shard {SHARD_INDEX} of {NUM_SHARDS}")
print(f"Scripts found:",
      os.path.exists(NORMALIZE_SCRIPT),
      os.path.exists(EXTRACT_SCRIPT),
      os.path.exists(COMBINE_SCRIPT))
# Out:
# This notebook = shard 1 of 5
# Scripts found: True True True

# %% [markdown]
# ## Smoke test (run ONCE, in a single notebook)
#
# No shard arguments = single-case test on BT0791. Normalizes that one case, then
# extracts it and prints the feature count. Confirms there is no GLCM hang before
# you commit all 5 machines.

# %%
# !python "{NORMALIZE_SCRIPT}"
# !python "{EXTRACT_SCRIPT}"
# Out:
# SMOKE TEST MODE: normalizing only BT0791
#
# Normalizing: BT0791
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Smoke test done.
# Fixed bin Count enabled! However, we recommend using a fixed bin Width. See http://pyradiomics.readthedocs.io/en/latest/faq.html#radiomics-fixed-bin-width for more details
# Extractor settings:
# {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binCount': 64}
#
# SMOKE TEST MODE: extracting only BT0791, nothing will be written.
#
# Extracting features for: BT0791
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> SMOKE TEST: 4224 features extracted (no hang).
#   -> sample keys: ['FLAIR_original_firstorder_10Percentile', 'FLAIR_original_firstorder_90Percentile', 'FLAIR_original_firstorder_Energy', 'FLAIR_original_firstorder_Entropy', 'FLAIR_original_firstorder_InterquartileRange']
#
# Smoke test done.

# %% [markdown]
# ## Step 1: Normalize (run in ALL 5 notebooks)
#
# Each notebook normalizes its own one-fifth of the cases. Wait for all 5 to finish
# before Step 2, because extraction reads the `_norm` files produced here.

# %%
# !python "{NORMALIZE_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Shard 1 of 5. Total case folders: 2061
#
# Normalizing: BT0002
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0009
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0019
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0026
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0034
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0045
#   -> flair: brain mean 839.07, std 282.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 985.60, std 174.12 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1090.33, std 183.31 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1259.14, std 537.59 -> saved t2_norm.nii.gz
#
# Normalizing: BT0059
#   -> flair: brain mean 519.24, std 126.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 838.76, std 255.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 796.63, std 182.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 799.60, std 245.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT0065
#   -> flair: brain mean 293.58, std 69.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 615.44, std 99.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 625.49, std 109.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 452.93, std 178.10 -> saved t2_norm.nii.gz
#
# Normalizing: BT0076
#   -> flair: brain mean 1531.26, std 370.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2041.80, std 379.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 10887.03, std 2596.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1005.34, std 240.77 -> saved t2_norm.nii.gz
#
# Normalizing: BT0084
#   -> flair: brain mean 593.87, std 169.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 725.90, std 251.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 653.74, std 190.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 952.74, std 368.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT0091
#   -> flair: brain mean 551.44, std 146.66 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 562.47, std 170.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 544.00, std 179.56 -> saved t1_norm.nii.gz
#   -> t2: brain mean 851.54, std 222.59 -> saved t2_norm.nii.gz
#
# Normalizing: BT0102
#   -> flair: brain mean 524.52, std 112.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 492.09, std 93.64 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 442.95, std 57.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 504.59, std 121.31 -> saved t2_norm.nii.gz
#
# Normalizing: BT0112
#   -> flair: brain mean 294.05, std 63.27 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 299.78, std 66.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 291.75, std 71.56 -> saved t1_norm.nii.gz
#   -> t2: brain mean 323.01, std 84.84 -> saved t2_norm.nii.gz
#
# Normalizing: BT0122
#   -> flair: brain mean 486.24, std 175.65 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 636.80, std 222.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 630.02, std 226.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 994.80, std 413.17 -> saved t2_norm.nii.gz
#
# Normalizing: BT0129
#   -> flair: brain mean 21545.57, std 4256.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 26586.35, std 4221.75 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 26410.71, std 4580.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 7142.44, std 2040.98 -> saved t2_norm.nii.gz
#
# Normalizing: BT0138
#   -> flair: brain mean 931.38, std 250.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1132.43, std 194.01 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 776.45, std 138.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 798.40, std 225.51 -> saved t2_norm.nii.gz
#
# Normalizing: BT0143
#   -> flair: brain mean 263.15, std 72.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 472.01, std 84.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 393.87, std 74.76 -> saved t1_norm.nii.gz
#   -> t2: brain mean 260.03, std 206.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT0148
#   -> flair: brain mean 301.62, std 73.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 661.47, std 104.46 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 508.02, std 98.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 386.76, std 143.21 -> saved t2_norm.nii.gz
#
# Normalizing: BT0156
#   -> flair: brain mean 461.15, std 124.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1293.27, std 366.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 636.40, std 115.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 805.42, std 257.95 -> saved t2_norm.nii.gz
#
# Normalizing: BT0162
#   -> flair: brain mean 566.54, std 144.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 773.76, std 159.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 677.13, std 109.09 -> saved t1_norm.nii.gz
#   -> t2: brain mean 200.88, std 60.88 -> saved t2_norm.nii.gz
#
# Normalizing: BT0170
#   -> flair: brain mean 280.44, std 71.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 809.76, std 149.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 588.99, std 110.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 483.10, std 164.99 -> saved t2_norm.nii.gz
#
# Normalizing: BT0182
#   -> flair: brain mean 62.78, std 14.88 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 729.63, std 180.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 440.66, std 125.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 776.54, std 286.01 -> saved t2_norm.nii.gz
#
# Normalizing: BT0189
#   -> flair: brain mean 245.09, std 54.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 646.90, std 125.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 605.24, std 142.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 573.86, std 206.72 -> saved t2_norm.nii.gz
#
# Normalizing: BT0196
#   -> flair: brain mean 265.20, std 73.33 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 388.89, std 67.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 385.67, std 68.52 -> saved t1_norm.nii.gz
#   -> t2: brain mean 465.27, std 114.22 -> saved t2_norm.nii.gz
#
# Normalizing: BT0206
#   -> flair: brain mean 41460.99, std 11000.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 71486.20, std 16142.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 70751.05, std 17907.98 -> saved t1_norm.nii.gz
#   -> t2: brain mean 36180.30, std 9489.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT0216
#   -> flair: brain mean 204.81, std 54.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 352.77, std 73.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 337.94, std 82.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 512.40, std 221.82 -> saved t2_norm.nii.gz
#
# Normalizing: BT0223
#   -> flair: brain mean 247.66, std 62.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 420.03, std 76.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 485.94, std 79.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 340.93, std 213.28 -> saved t2_norm.nii.gz
#
# Normalizing: BT0228
#   -> flair: brain mean 420.71, std 91.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 700.61, std 83.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 716.40, std 87.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 493.87, std 220.44 -> saved t2_norm.nii.gz
#
# Normalizing: BT0237
#   -> flair: brain mean 414.75, std 97.41 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 654.07, std 152.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 592.49, std 146.45 -> saved t1_norm.nii.gz
#   -> t2: brain mean 608.84, std 179.90 -> saved t2_norm.nii.gz
#
# Normalizing: BT0246
#   -> flair: brain mean 270.56, std 59.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 729.77, std 130.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 684.47, std 136.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 645.55, std 191.04 -> saved t2_norm.nii.gz
#
# Normalizing: BT0254
#   -> flair: brain mean 486.31, std 94.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1165.03, std 159.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1384.99, std 221.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 621.98, std 155.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT0268
#   -> flair: brain mean 1469.90, std 396.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5084.86, std 1953.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 953.77, std 354.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 679.53, std 170.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT0276
#   -> flair: brain mean 443.97, std 132.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 31529.75, std 9277.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 530.29, std 204.52 -> saved t1_norm.nii.gz
#   -> t2: brain mean 779.68, std 225.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT0283
#   -> flair: brain mean 414.18, std 105.52 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1395.91, std 187.48 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1053.82, std 141.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 535.29, std 215.62 -> saved t2_norm.nii.gz
#
# Normalizing: BT0291
#   -> flair: brain mean 176.23, std 42.41 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1850.09, std 386.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 488.96, std 88.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 799.18, std 364.74 -> saved t2_norm.nii.gz
#
# Normalizing: BT0299
#   -> flair: brain mean 137.45, std 33.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 760.59, std 112.75 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 773.66, std 133.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 361.47, std 129.08 -> saved t2_norm.nii.gz
#
# Normalizing: BT0307
#   -> flair: brain mean 495.74, std 134.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 679.40, std 234.79 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 471.14, std 150.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 768.73, std 286.37 -> saved t2_norm.nii.gz
#
# Normalizing: BT0315
#   -> flair: brain mean 345.03, std 100.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 764.73, std 119.50 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 757.55, std 122.41 -> saved t1_norm.nii.gz
#   -> t2: brain mean 469.24, std 268.02 -> saved t2_norm.nii.gz
#
# Normalizing: BT0324
#   -> flair: brain mean 327.11, std 59.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 540.82, std 74.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 491.79, std 67.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 318.15, std 87.18 -> saved t2_norm.nii.gz
#
# Normalizing: BT0336
#   -> flair: brain mean 151.22, std 32.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 313.70, std 53.46 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 295.76, std 47.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 181.66, std 79.80 -> saved t2_norm.nii.gz
#
# Normalizing: BT0347
#   -> flair: brain mean 332.98, std 70.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 487.01, std 76.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 485.71, std 73.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 439.67, std 135.36 -> saved t2_norm.nii.gz
#
# Normalizing: BT0360
#   -> flair: brain mean 215.80, std 57.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 501.84, std 85.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 511.78, std 78.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 231.04, std 34.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT0367
#   -> flair: brain mean 515.17, std 119.11 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 10643.87, std 3090.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1464.99, std 412.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 688.14, std 165.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT0377
#   -> flair: brain mean 7232.79, std 1539.27 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1680.27, std 321.93 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2014.90, std 416.11 -> saved t1_norm.nii.gz
#   -> t2: brain mean 9247.54, std 2889.26 -> saved t2_norm.nii.gz
#
# Normalizing: BT0394
#   -> flair: brain mean 303.86, std 79.88 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 543.56, std 102.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 637.38, std 114.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 577.49, std 250.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT0405
#   -> flair: brain mean 252.90, std 72.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 584.93, std 113.35 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 557.46, std 110.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 524.22, std 250.00 -> saved t2_norm.nii.gz
#
# Normalizing: BT0412
#   -> flair: brain mean 187.14, std 67.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1068.64, std 183.53 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 870.70, std 150.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 551.11, std 287.35 -> saved t2_norm.nii.gz
#
# Normalizing: BT0424
#   -> flair: brain mean 389.98, std 92.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 679.67, std 85.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 574.72, std 93.51 -> saved t1_norm.nii.gz
#   -> t2: brain mean 475.12, std 146.98 -> saved t2_norm.nii.gz
#
# Normalizing: BT0432
#   -> flair: brain mean 8951.67, std 1589.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2726.37, std 463.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 6782.96, std 1238.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 5430.59, std 1687.01 -> saved t2_norm.nii.gz
#
# Normalizing: BT0450
#   -> flair: brain mean 500.33, std 133.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1284.34, std 236.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1321.26, std 218.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 920.48, std 293.86 -> saved t2_norm.nii.gz
#
# Normalizing: BT0462
#   -> flair: brain mean 415.38, std 106.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 663.38, std 85.52 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 994.23, std 152.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 603.40, std 261.28 -> saved t2_norm.nii.gz
#
# Normalizing: BT0469
#   -> flair: brain mean 20684.08, std 4822.91 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 44730.82, std 6732.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 43169.27, std 7567.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 11001.12, std 3141.22 -> saved t2_norm.nii.gz
#
# Normalizing: BT0482
#   -> flair: brain mean 529.99, std 117.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 855.72, std 111.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1006.94, std 161.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 742.76, std 278.51 -> saved t2_norm.nii.gz
#
# Normalizing: BT0490
#   -> flair: brain mean 442.96, std 101.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 441.46, std 75.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 642.33, std 99.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 523.01, std 128.10 -> saved t2_norm.nii.gz
#
# Normalizing: BT0507
#   -> flair: brain mean 285.86, std 59.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 656.56, std 86.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 573.99, std 87.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 335.85, std 110.70 -> saved t2_norm.nii.gz
#
# Normalizing: BT0537
#   -> flair: brain mean 213.57, std 36.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 859.94, std 131.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 929.48, std 149.20 -> saved t1_norm.nii.gz
#   -> t2: brain mean 527.01, std 200.60 -> saved t2_norm.nii.gz
#
# Normalizing: BT0606
#   -> flair: brain mean 302.03, std 95.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 585.19, std 111.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 576.78, std 102.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 428.04, std 146.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT0614
#   -> flair: brain mean 311.68, std 67.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 470.41, std 85.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 468.48, std 102.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 484.26, std 118.39 -> saved t2_norm.nii.gz
#
# Normalizing: BT0621
#   -> flair: brain mean 656.35, std 201.12 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1322.76, std 207.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1310.07, std 323.13 -> saved t1_norm.nii.gz
#   -> t2: brain mean 628.97, std 300.70 -> saved t2_norm.nii.gz
#
# Normalizing: BT0626
#   -> flair: brain mean 433.90, std 88.51 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 519.90, std 87.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 548.52, std 78.58 -> saved t1_norm.nii.gz
#   -> t2: brain mean 456.46, std 125.18 -> saved t2_norm.nii.gz
#
# Normalizing: BT0633
#   -> flair: brain mean 403.87, std 116.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 728.16, std 182.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 870.26, std 157.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 907.16, std 223.78 -> saved t2_norm.nii.gz
#
# Normalizing: BT0639
#   -> flair: brain mean 104.00, std 33.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 390.54, std 186.55 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 329.70, std 69.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 324.63, std 134.48 -> saved t2_norm.nii.gz
#
# Normalizing: BT0647
#   -> flair: brain mean 169.41, std 46.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 760.55, std 107.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 726.17, std 108.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 399.07, std 147.52 -> saved t2_norm.nii.gz
#
# Normalizing: BT0656
#   -> flair: brain mean 489.98, std 96.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 685.61, std 155.59 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 647.14, std 158.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 749.65, std 202.93 -> saved t2_norm.nii.gz
#
# Normalizing: BT0667
#   -> flair: brain mean 473.79, std 131.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 468.30, std 84.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 492.53, std 82.56 -> saved t1_norm.nii.gz
#   -> t2: brain mean 718.14, std 270.48 -> saved t2_norm.nii.gz
#
# Normalizing: BT0675
#   -> flair: brain mean 287.07, std 63.37 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 595.84, std 83.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 334.31, std 65.92 -> saved t1_norm.nii.gz
#   -> t2: brain mean 385.54, std 133.47 -> saved t2_norm.nii.gz
#
# Normalizing: BT0681
#   -> flair: brain mean 492.86, std 116.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 679.92, std 165.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 624.87, std 176.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 829.35, std 239.99 -> saved t2_norm.nii.gz
#
# Normalizing: BT0692
#   -> flair: brain mean 434.30, std 78.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 788.49, std 94.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 403.14, std 107.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 467.59, std 195.55 -> saved t2_norm.nii.gz
#
# Normalizing: BT0704
#   -> flair: brain mean 139.19, std 36.61 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 305.89, std 62.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 141.13, std 21.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 151.12, std 52.68 -> saved t2_norm.nii.gz
#
# Normalizing: BT0716
#   -> flair: brain mean 187.05, std 49.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 730.72, std 133.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 703.63, std 142.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 516.71, std 252.14 -> saved t2_norm.nii.gz
#
# Normalizing: BT0725
#   -> flair: brain mean 784.17, std 166.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1445.72, std 236.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3109.44, std 628.85 -> saved t1_norm.nii.gz
#   -> t2: brain mean 981.51, std 279.15 -> saved t2_norm.nii.gz
#
# Normalizing: BT0733
#   -> flair: brain mean 408.13, std 135.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 494.74, std 92.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 454.93, std 77.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 490.51, std 194.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT0740
#   -> flair: brain mean 246.98, std 78.81 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 806.89, std 137.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 773.80, std 127.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1031.64, std 491.40 -> saved t2_norm.nii.gz
#
# Normalizing: BT0748
#   -> flair: brain mean 211.16, std 46.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 513.25, std 79.93 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 593.74, std 105.45 -> saved t1_norm.nii.gz
#   -> t2: brain mean 417.04, std 155.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0753
#   -> flair: brain mean 474.55, std 90.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 840.75, std 100.89 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 842.91, std 105.34 -> saved t1_norm.nii.gz
#   -> t2: brain mean 513.83, std 146.02 -> saved t2_norm.nii.gz
#
# Normalizing: BT0762
#   -> flair: brain mean 5635.02, std 1487.11 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 15979.84, std 5344.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 14496.77, std 4909.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 3603.76, std 1169.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0768
#   -> flair: brain mean 578.23, std 156.11 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1203.91, std 219.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1086.76, std 206.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1028.97, std 310.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0777
#   -> flair: brain mean 502.44, std 97.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 938.73, std 219.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 896.52, std 244.37 -> saved t1_norm.nii.gz
#   -> t2: brain mean 865.42, std 252.20 -> saved t2_norm.nii.gz
#
# Normalizing: BT0785
#   -> flair: brain mean 278.63, std 76.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 351.88, std 60.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 288.87, std 52.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 371.13, std 137.58 -> saved t2_norm.nii.gz
#
# Normalizing: BT0791
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0802
#   -> flair: brain mean 256.74, std 54.88 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 468.06, std 67.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 475.19, std 101.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 323.17, std 116.74 -> saved t2_norm.nii.gz
#
# Normalizing: BT0812
#   -> flair: brain mean 410.80, std 86.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 309.25, std 86.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 469.02, std 85.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 567.88, std 267.52 -> saved t2_norm.nii.gz
#
# Normalizing: BT0823
#   -> flair: brain mean 304.87, std 76.66 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 195.26, std 61.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 169.72, std 52.91 -> saved t1_norm.nii.gz
#   -> t2: brain mean 322.45, std 105.76 -> saved t2_norm.nii.gz
#
# Normalizing: BT0835
#   -> flair: brain mean 333.87, std 90.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 611.44, std 139.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 557.65, std 93.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 494.24, std 156.87 -> saved t2_norm.nii.gz
#
# Normalizing: BT0842
#   -> flair: brain mean 149.31, std 31.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 465.88, std 102.02 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 381.66, std 104.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 201.39, std 138.37 -> saved t2_norm.nii.gz
#
# Normalizing: BT0904
#   -> flair: brain mean 437.09, std 111.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 810.21, std 160.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 783.16, std 113.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 555.24, std 207.45 -> saved t2_norm.nii.gz
#
# Normalizing: BT0914
#   -> flair: brain mean 786.21, std 256.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2396.04, std 520.87 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2378.67, std 354.31 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1683.34, std 858.45 -> saved t2_norm.nii.gz
#
# Normalizing: BT0926
#   -> flair: brain mean 57306.91, std 15333.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 98643.25, std 19472.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 108118.73, std 24053.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 36253.69, std 10234.19 -> saved t2_norm.nii.gz
#
# Normalizing: BT0932
#   -> flair: brain mean 300.46, std 90.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 688.17, std 109.83 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 706.62, std 117.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 522.91, std 249.76 -> saved t2_norm.nii.gz
#
# Normalizing: BT0950
#   -> flair: brain mean 303.35, std 52.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 426.60, std 54.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 418.02, std 48.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 401.79, std 122.98 -> saved t2_norm.nii.gz
#
# Normalizing: BT0958
#   -> flair: brain mean 833.30, std 163.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1960.08, std 293.86 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 927.35, std 161.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 851.44, std 195.74 -> saved t2_norm.nii.gz
#
# Normalizing: BT0964
#   -> flair: brain mean 1612.03, std 349.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 855.64, std 158.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1118.00, std 234.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 579.50, std 196.19 -> saved t2_norm.nii.gz
#
# Normalizing: BT0972
#   -> flair: brain mean 1821.30, std 428.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2840.40, std 368.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2698.81, std 348.56 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1856.13, std 489.88 -> saved t2_norm.nii.gz
#
# Normalizing: BT1010
#   -> flair: brain mean 428.05, std 101.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1273.37, std 156.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1289.24, std 177.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 599.19, std 172.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT1017
#   -> flair: brain mean 362.32, std 70.26 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 510.71, std 112.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 597.61, std 141.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 612.47, std 169.88 -> saved t2_norm.nii.gz
#
# Normalizing: BT1023
#   -> flair: brain mean 282.38, std 67.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 491.05, std 89.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 583.84, std 141.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 367.25, std 138.27 -> saved t2_norm.nii.gz
#
# Normalizing: BT1029
#   -> flair: brain mean 384.87, std 118.52 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 553.00, std 148.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 778.96, std 123.90 -> saved t1_norm.nii.gz
#   -> t2: brain mean 518.96, std 253.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT1036
#   -> flair: brain mean 347.20, std 104.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1145.66, std 196.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1078.71, std 200.63 -> saved t1_norm.nii.gz
#   -> t2: brain mean 566.71, std 248.57 -> saved t2_norm.nii.gz
#
# Normalizing: BT1042
#   -> flair: brain mean 258.38, std 58.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 429.51, std 100.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 416.94, std 104.18 -> saved t1_norm.nii.gz
#   -> t2: brain mean 231.66, std 141.84 -> saved t2_norm.nii.gz
#
# Normalizing: BT1053
#   -> flair: brain mean 256.81, std 67.91 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 389.66, std 50.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 716.23, std 99.20 -> saved t1_norm.nii.gz
#   -> t2: brain mean 385.09, std 105.52 -> saved t2_norm.nii.gz
#
# Normalizing: BT1067
#   -> flair: brain mean 569.47, std 158.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1417.30, std 176.44 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1617.00, std 209.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 786.80, std 271.90 -> saved t2_norm.nii.gz
#
# Normalizing: BT1073
#   -> flair: brain mean 808.43, std 182.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1228.37, std 325.86 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 597.58, std 177.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1031.37, std 221.22 -> saved t2_norm.nii.gz
#
# Normalizing: BT1082
#   -> flair: brain mean 478.45, std 137.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 406.50, std 68.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 372.46, std 66.76 -> saved t1_norm.nii.gz
#   -> t2: brain mean 388.98, std 121.25 -> saved t2_norm.nii.gz
#
# Normalizing: BT1087
#   -> flair: brain mean 1555.72, std 362.59 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2923.78, std 807.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1144.58, std 265.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1333.94, std 771.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT1094
#   -> flair: brain mean 342.22, std 111.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 910.98, std 166.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 883.06, std 168.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 512.19, std 220.61 -> saved t2_norm.nii.gz
#
# Normalizing: BT1100
#   -> flair: brain mean 257.79, std 83.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 350.01, std 120.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 323.56, std 117.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 319.29, std 183.72 -> saved t2_norm.nii.gz
#
# Normalizing: BT1106
#   -> flair: brain mean 1063.19, std 332.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 798.28, std 170.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1064.04, std 192.67 -> saved t1_norm.nii.gz
#   -> t2: brain mean 647.67, std 261.84 -> saved t2_norm.nii.gz
#
# Normalizing: BT1112
#   -> flair: brain mean 461.60, std 123.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2631.99, std 739.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 792.62, std 138.31 -> saved t1_norm.nii.gz
#   -> t2: brain mean 708.93, std 257.86 -> saved t2_norm.nii.gz
#
# Normalizing: BT1117
#   -> flair: brain mean 1066.80, std 247.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 779.33, std 206.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1642.76, std 485.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 591.09, std 201.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT1124
#   -> flair: brain mean 337.83, std 101.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 634.66, std 199.16 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 557.09, std 193.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 885.43, std 283.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT1131
#   -> flair: brain mean 212.98, std 63.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 276.85, std 86.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 272.41, std 86.82 -> saved t1_norm.nii.gz
#   -> t2: brain mean 412.56, std 129.78 -> saved t2_norm.nii.gz
#
# Normalizing: BT1139
#   -> flair: brain mean 213.11, std 47.11 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 373.32, std 105.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 334.37, std 107.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 320.21, std 101.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT1147
#   -> flair: brain mean 52908.09, std 11500.92 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 118743.51, std 24353.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 118321.98, std 28526.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 39894.84, std 10558.54 -> saved t2_norm.nii.gz
#
# Normalizing: BT1205
#   -> flair: brain mean 739.92, std 152.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1299.28, std 286.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1046.72, std 230.58 -> saved t1_norm.nii.gz
#   -> t2: brain mean 808.78, std 166.40 -> saved t2_norm.nii.gz
#
# Normalizing: BT1215
#   -> flair: brain mean 218.56, std 49.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 265.86, std 45.79 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 241.06, std 42.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 249.94, std 70.00 -> saved t2_norm.nii.gz
#
# Normalizing: BT1229
#   -> flair: brain mean 261.41, std 58.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 479.20, std 114.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 400.69, std 113.11 -> saved t1_norm.nii.gz
#   -> t2: brain mean 368.67, std 130.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT1236
#   -> flair: brain mean 404.01, std 109.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 371.80, std 64.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 349.19, std 65.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 402.29, std 169.30 -> saved t2_norm.nii.gz
#
# Normalizing: BT1245
#   -> flair: brain mean 603.90, std 159.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1076.04, std 174.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 990.87, std 150.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 842.72, std 282.29 -> saved t2_norm.nii.gz
#
# Normalizing: BT1252
#   -> flair: brain mean 858.66, std 262.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 850.50, std 185.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 553.45, std 148.41 -> saved t1_norm.nii.gz
#   -> t2: brain mean 790.29, std 220.13 -> saved t2_norm.nii.gz
#
# Normalizing: BT1262
#   -> flair: brain mean 1136.54, std 267.92 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 930.29, std 171.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 982.30, std 135.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 865.75, std 251.80 -> saved t2_norm.nii.gz
#
# Normalizing: BT1270
#   -> flair: brain mean 294.72, std 89.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 824.90, std 139.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 774.11, std 140.49 -> saved t1_norm.nii.gz
#   -> t2: brain mean 421.33, std 175.05 -> saved t2_norm.nii.gz
#
# Normalizing: BT1276
#   -> flair: brain mean 214.71, std 64.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 444.86, std 75.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 433.31, std 64.90 -> saved t1_norm.nii.gz
#   -> t2: brain mean 281.46, std 80.17 -> saved t2_norm.nii.gz
#
# Normalizing: BT1283
#   -> flair: brain mean 383.00, std 74.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 804.82, std 159.52 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 750.99, std 173.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 485.36, std 154.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT1289
#   -> flair: brain mean 548.12, std 131.03 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1067.33, std 152.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1058.75, std 165.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 740.89, std 202.13 -> saved t2_norm.nii.gz
#
# Normalizing: BT1301
#   -> flair: brain mean 198.13, std 45.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 419.65, std 56.87 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 386.84, std 59.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 246.98, std 80.06 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0002
#   -> flair: brain mean 228.29, std 55.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 121.49, std 27.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 669.79, std 103.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 271.60, std 90.06 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0007
#   -> flair: brain mean 1710.91, std 561.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2594.44, std 860.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2997.13, std 431.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1391.29, std 761.02 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0012
#   -> flair: brain mean 146.02, std 52.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 198.23, std 40.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 169.77, std 36.18 -> saved t1_norm.nii.gz
#   -> t2: brain mean 176.91, std 61.73 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0017
#   -> flair: brain mean 277.98, std 82.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 400.03, std 80.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 320.67, std 64.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 366.96, std 138.94 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0022
#   -> flair: brain mean 228.01, std 52.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 316.77, std 58.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 422.71, std 76.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 328.06, std 120.23 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0027
#   -> flair: brain mean 156.15, std 42.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 75.41, std 32.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 363.81, std 71.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 231.40, std 86.49 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0032
#   -> flair: brain mean 274.37, std 93.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 294.08, std 76.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 358.66, std 73.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 310.20, std 152.10 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0037
#   -> flair: brain mean 1931.60, std 635.92 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2048.20, std 687.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2435.96, std 354.81 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1159.93, std 669.04 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0042
#   -> flair: brain mean 338.18, std 75.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 447.00, std 81.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 483.20, std 78.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 387.22, std 92.52 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0047
#   -> flair: brain mean 287.87, std 58.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 721.24, std 100.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 420.15, std 71.52 -> saved t1_norm.nii.gz
#   -> t2: brain mean 406.42, std 141.69 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0052
#   -> flair: brain mean 751.55, std 265.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 744.59, std 255.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 621.62, std 151.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 800.37, std 356.05 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0057
#   -> flair: brain mean 289.68, std 52.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 395.45, std 57.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 412.47, std 69.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 339.50, std 110.44 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0062
#   -> flair: brain mean 387.77, std 113.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 393.42, std 129.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 394.88, std 88.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 520.80, std 188.93 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0067
#   -> flair: brain mean 1041.51, std 366.70 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 816.99, std 243.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 680.71, std 134.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 399.07, std 204.09 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0072
#   -> flair: brain mean 1342.79, std 381.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1629.90, std 503.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1358.18, std 183.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 724.75, std 461.11 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0077
#   -> flair: brain mean 279.17, std 107.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 261.72, std 86.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 337.69, std 78.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 323.92, std 112.73 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0082
#   -> flair: brain mean 282.74, std 84.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 360.31, std 75.64 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 251.96, std 57.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 414.15, std 157.41 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0087
#   -> flair: brain mean 643.47, std 172.81 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 750.37, std 150.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 548.01, std 128.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 958.92, std 245.53 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0092
#   -> flair: brain mean 1562.65, std 504.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4111.27, std 1111.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1988.68, std 188.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 3127.57, std 1902.18 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0097
#   -> flair: brain mean 922.16, std 291.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 746.47, std 211.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 708.99, std 233.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 812.19, std 294.73 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0102
#   -> flair: brain mean 762.48, std 202.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 728.20, std 221.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 624.20, std 124.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 873.05, std 345.88 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0107
#   -> flair: brain mean 333.31, std 72.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 311.16, std 54.16 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 298.13, std 58.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 443.76, std 149.89 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0112
#   -> flair: brain mean 194.53, std 61.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 202.91, std 44.59 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 317.10, std 62.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 316.02, std 100.01 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0117
#   -> flair: brain mean 549.66, std 152.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1025.55, std 367.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 719.13, std 239.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 517.80, std 415.64 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0122
#   -> flair: brain mean 265.13, std 54.95 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 631.81, std 88.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 646.51, std 96.90 -> saved t1_norm.nii.gz
#   -> t2: brain mean 506.58, std 156.04 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0127
#   -> flair: brain mean 356.47, std 114.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 282.60, std 63.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 367.33, std 76.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 502.98, std 175.04 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0132
#   -> flair: brain mean 1101.18, std 322.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 802.41, std 229.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 926.11, std 200.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 661.60, std 358.18 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0137
#   -> flair: brain mean 736.09, std 229.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 710.60, std 219.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 583.08, std 168.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 405.55, std 206.81 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0142
#   -> flair: brain mean 771.19, std 288.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3309.21, std 932.35 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2814.81, std 754.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1666.82, std 866.08 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0147
#   -> flair: brain mean 328.58, std 99.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 142.93, std 38.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 142.54, std 33.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 396.46, std 76.06 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0152
#   -> flair: brain mean 1232.98, std 470.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4167.27, std 1368.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1451.72, std 295.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1540.31, std 885.93 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0157
#   -> flair: brain mean 350.57, std 102.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 438.38, std 90.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 447.91, std 92.63 -> saved t1_norm.nii.gz
#   -> t2: brain mean 583.04, std 173.00 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0162
#   -> flair: brain mean 1142.92, std 295.24 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1491.97, std 455.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1361.95, std 197.92 -> saved t1_norm.nii.gz
#   -> t2: brain mean 829.24, std 392.10 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0167
#   -> flair: brain mean 640.60, std 201.59 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 963.38, std 376.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 989.61, std 188.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 546.98, std 339.61 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0172
#   -> flair: brain mean 346.59, std 105.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 344.65, std 84.67 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 236.33, std 60.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 425.68, std 184.28 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0177
#   -> flair: brain mean 705.58, std 216.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 827.13, std 248.53 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 510.09, std 153.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 417.89, std 231.10 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0182
#   -> flair: brain mean 1468.65, std 580.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4767.78, std 1985.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2923.38, std 442.34 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1987.22, std 955.53 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0187
#   -> flair: brain mean 1252.68, std 332.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3634.08, std 782.04 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2728.34, std 371.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1212.51, std 652.20 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0192
#   -> flair: brain mean 1019.32, std 365.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1412.59, std 551.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1213.47, std 206.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 759.03, std 433.41 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0197
#   -> flair: brain mean 334.46, std 95.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 272.35, std 84.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 335.98, std 74.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 323.24, std 64.53 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0202
#   -> flair: brain mean 224.53, std 77.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 270.47, std 69.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 222.00, std 44.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 346.39, std 143.12 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0207
#   -> flair: brain mean 121.06, std 33.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 81.35, std 31.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 419.38, std 72.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 257.99, std 95.28 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0212
#   -> flair: brain mean 221.11, std 69.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 318.30, std 71.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 297.36, std 55.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 329.26, std 103.85 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0217
#   -> flair: brain mean 1359.04, std 275.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 730.05, std 196.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1612.26, std 275.90 -> saved t1_norm.nii.gz
#   -> t2: brain mean 598.97, std 333.75 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0222
#   -> flair: brain mean 706.99, std 219.69 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 819.37, std 239.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 641.73, std 148.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 396.62, std 202.81 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0227
#   -> flair: brain mean 274.37, std 48.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 326.98, std 87.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 461.35, std 81.73 -> saved t1_norm.nii.gz
# ...
#
# Normalizing: UCSF-PDGM-0266_nifti
#   -> flair: brain mean 1127.13, std 444.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3185.23, std 966.01 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2667.37, std 747.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 659.03, std 298.99 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0272_nifti
#   -> flair: brain mean 991.40, std 320.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4042.25, std 1195.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3028.07, std 878.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 293.50, std 179.09 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0277_nifti
#   -> flair: brain mean 1553.84, std 572.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4874.33, std 1717.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1097.65, std 171.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1113.75, std 575.67 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0283_nifti
#   -> flair: brain mean 1258.60, std 464.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4588.80, std 1384.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3346.35, std 842.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 552.93, std 232.82 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0288_nifti
#   -> flair: brain mean 947.02, std 326.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4470.07, std 1486.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3593.70, std 1034.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 682.76, std 392.54 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0297_nifti
#   -> flair: brain mean 1169.40, std 446.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4447.26, std 1230.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2474.47, std 772.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 790.55, std 374.22 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0304_nifti
#   -> flair: brain mean 812.81, std 301.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3854.79, std 1289.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1016.76, std 147.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 577.76, std 275.74 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0309_nifti
#   -> flair: brain mean 823.51, std 321.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4347.44, std 1307.48 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4401.59, std 1138.83 -> saved t1_norm.nii.gz
#   -> t2: brain mean 729.09, std 374.22 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0314_nifti
#   -> flair: brain mean 1126.19, std 400.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3466.64, std 1030.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2686.73, std 754.09 -> saved t1_norm.nii.gz
#   -> t2: brain mean 482.53, std 246.52 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0320_nifti
#   -> flair: brain mean 908.56, std 278.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4575.30, std 1424.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3439.17, std 976.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 380.80, std 151.06 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0326_nifti
#   -> flair: brain mean 1605.97, std 489.35 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3747.02, std 1126.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2759.34, std 775.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 590.79, std 268.80 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0331_nifti
#   -> flair: brain mean 1209.15, std 458.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2291.07, std 931.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1289.67, std 247.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 659.51, std 368.31 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0336_nifti
#   -> flair: brain mean 1112.78, std 334.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2543.76, std 1080.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1390.92, std 242.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 586.43, std 306.49 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0341_nifti
#   -> flair: brain mean 1315.75, std 417.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2924.19, std 1065.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1554.62, std 289.40 -> saved t1_norm.nii.gz
#   -> t2: brain mean 661.52, std 362.57 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0346_nifti
#   -> flair: brain mean 1000.64, std 407.87 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3944.26, std 1227.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3607.07, std 865.51 -> saved t1_norm.nii.gz
#   -> t2: brain mean 758.65, std 441.20 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0351_nifti
#   -> flair: brain mean 1544.19, std 484.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5425.46, std 1627.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4116.89, std 1100.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 478.72, std 195.28 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0356_nifti
#   -> flair: brain mean 870.41, std 304.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3212.08, std 743.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3331.17, std 857.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 620.86, std 257.47 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0361_nifti
#   -> flair: brain mean 987.73, std 308.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6458.60, std 1788.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 5326.73, std 1441.92 -> saved t1_norm.nii.gz
#   -> t2: brain mean 494.92, std 201.51 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0366_nifti
#   -> flair: brain mean 985.48, std 415.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2577.60, std 679.86 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2393.11, std 571.49 -> saved t1_norm.nii.gz
#   -> t2: brain mean 735.18, std 336.21 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0371_nifti
#   -> flair: brain mean 1053.09, std 328.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4756.49, std 1354.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3389.14, std 977.87 -> saved t1_norm.nii.gz
#   -> t2: brain mean 493.85, std 184.25 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0376_nifti
#   -> flair: brain mean 1041.44, std 425.87 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3113.51, std 1060.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2478.17, std 754.03 -> saved t1_norm.nii.gz
#   -> t2: brain mean 643.07, std 320.34 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0381_nifti
#   -> flair: brain mean 992.12, std 383.37 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3742.06, std 1381.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2808.53, std 919.70 -> saved t1_norm.nii.gz
#   -> t2: brain mean 906.85, std 482.20 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0386_nifti
#   -> flair: brain mean 337.59, std 141.98 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2533.18, std 883.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2204.50, std 683.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1046.98, std 539.09 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0391_nifti
#   -> flair: brain mean 780.88, std 309.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3442.86, std 1129.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3252.12, std 934.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 699.57, std 363.95 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0396_nifti
#   -> flair: brain mean 1256.77, std 406.98 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3930.11, std 1234.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1319.21, std 232.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 586.54, std 292.21 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0401_nifti
#   -> flair: brain mean 898.16, std 384.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1991.75, std 800.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1044.86, std 188.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 723.02, std 432.88 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0406_nifti
#   -> flair: brain mean 1014.35, std 365.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3673.47, std 1096.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3146.19, std 819.48 -> saved t1_norm.nii.gz
#   -> t2: brain mean 552.90, std 254.44 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0412_nifti
#   -> flair: brain mean 1061.38, std 397.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4000.15, std 1056.25 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1333.70, std 189.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 701.40, std 358.25 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0417_nifti
#   -> flair: brain mean 1031.53, std 386.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3055.47, std 1047.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2285.38, std 803.13 -> saved t1_norm.nii.gz
#   -> t2: brain mean 819.89, std 450.29 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0422_nifti
#   -> flair: brain mean 1007.06, std 345.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2625.97, std 1129.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1373.35, std 240.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 846.48, std 560.99 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0427_nifti
#   -> flair: brain mean 292.89, std 105.91 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1512.34, std 336.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1493.16, std 371.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 122.31, std 132.67 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0432_nifti
#   -> flair: brain mean 402.67, std 142.27 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2717.20, std 566.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1455.49, std 378.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 114.39, std 94.35 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0437_nifti
#   -> flair: brain mean 1230.09, std 442.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3277.85, std 945.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2759.90, std 840.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 691.62, std 393.56 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0442_nifti
#   -> flair: brain mean 1193.46, std 338.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2934.00, std 920.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1524.19, std 238.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 643.03, std 318.48 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0447_nifti
#   -> flair: brain mean 1048.81, std 303.12 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4139.23, std 1204.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3863.32, std 774.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 568.51, std 229.26 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0452_nifti
#   -> flair: brain mean 1157.99, std 374.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3767.34, std 1077.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3347.32, std 817.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 599.81, std 265.74 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0457_nifti
#   -> flair: brain mean 1364.15, std 449.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4281.13, std 995.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3870.01, std 891.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 536.34, std 213.28 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0462_nifti
#   -> flair: brain mean 1002.43, std 396.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3802.50, std 1219.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2460.48, std 826.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 744.44, std 338.48 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0467_nifti
#   -> flair: brain mean 967.23, std 371.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2250.60, std 827.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1934.95, std 343.23 -> saved t1_norm.nii.gz
#   -> t2: brain mean 982.02, std 573.54 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0472_nifti
#   -> flair: brain mean 1235.85, std 431.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3416.35, std 1163.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3031.05, std 803.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 810.87, std 422.05 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0477_nifti
#   -> flair: brain mean 1065.13, std 336.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4065.28, std 1156.86 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3229.14, std 959.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 668.37, std 294.84 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0482_nifti
#   -> flair: brain mean 1223.69, std 378.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2079.69, std 745.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1295.74, std 219.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 553.65, std 238.20 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0487_nifti
#   -> flair: brain mean 1157.07, std 380.87 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4071.98, std 1306.64 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3210.96, std 787.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 492.52, std 198.65 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0492_nifti
#   -> flair: brain mean 1245.46, std 468.41 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4052.82, std 1376.81 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3067.70, std 823.21 -> saved t1_norm.nii.gz
#   -> t2: brain mean 895.37, std 384.56 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0497_nifti
#   -> flair: brain mean 1166.36, std 434.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3958.71, std 1163.67 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2453.33, std 812.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 755.83, std 363.32 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0502_nifti
#   -> flair: brain mean 1055.08, std 427.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3130.50, std 1091.02 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2518.56, std 772.90 -> saved t1_norm.nii.gz
#   -> t2: brain mean 814.42, std 403.58 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0507_nifti
#   -> flair: brain mean 997.46, std 325.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3977.62, std 1185.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3223.31, std 920.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 749.25, std 328.38 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0512_nifti
#   -> flair: brain mean 1026.82, std 399.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3569.67, std 1246.02 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2477.93, std 830.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 701.81, std 341.08 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0517_nifti
#   -> flair: brain mean 732.06, std 293.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2536.69, std 802.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2176.13, std 717.05 -> saved t1_norm.nii.gz
#   -> t2: brain mean 521.73, std 241.43 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0522_nifti
#   -> flair: brain mean 879.93, std 305.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4154.02, std 1234.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3156.02, std 956.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 386.37, std 186.45 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0527_nifti
#   -> flair: brain mean 1248.77, std 430.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5005.92, std 1455.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3997.61, std 1019.34 -> saved t1_norm.nii.gz
#   -> t2: brain mean 511.76, std 233.59 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0532_nifti
#   -> flair: brain mean 922.39, std 297.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2521.14, std 838.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2448.75, std 696.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 620.09, std 297.63 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0537_nifti
#   -> flair: brain mean 950.93, std 318.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2495.39, std 798.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2382.77, std 732.99 -> saved t1_norm.nii.gz
#   -> t2: brain mean 577.26, std 263.27 -> saved t2_norm.nii.gz
#
# Shard 1 of 5 complete.

# %% [markdown]
# ## Step 2: Extract (run in ALL 5 notebooks, after Step 1 is fully done)
#
# Each notebook extracts its own one-fifth and writes one CSV per case into
# `features/per_case/`. Safe to run concurrently (no shared file).

# %%
# !python "{EXTRACT_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Streaming output truncated to the last 5000 lines.
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote TCGA-HT-8018.csv
# Extracting features for: UCSF-PDGM-0004_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0004_nifti.csv
# Extracting features for: UCSF-PDGM-0010_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0010_nifti.csv
# Extracting features for: UCSF-PDGM-0015_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0015_nifti.csv
# Extracting features for: UCSF-PDGM-0020_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0020_nifti.csv
# Extracting features for: UCSF-PDGM-0025_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0025_nifti.csv
# Extracting features for: UCSF-PDGM-0031_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0031_nifti.csv
# Extracting features for: UCSF-PDGM-0036_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0036_nifti.csv
# Extracting features for: UCSF-PDGM-0041_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0041_nifti.csv
# Extracting features for: UCSF-PDGM-0046_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0046_nifti.csv
# Extracting features for: UCSF-PDGM-0053_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0522_nifti.csv
# Extracting features for: UCSF-PDGM-0527_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0527_nifti.csv
# Extracting features for: UCSF-PDGM-0532_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0532_nifti.csv
# Extracting features for: UCSF-PDGM-0537_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0537_nifti.csv
#
# Shard 1 of 5 complete.

# %% [markdown]
# ## Step 3: Combine (run ONCE, in a single notebook, after all of Step 2 is done)
#
# Concatenates every per-case CSV into `all_radiomics_features.csv` and prints
# per-cohort counts plus any cases missing a sequence.

# %%
# !python "{COMBINE_SCRIPT}"
