# %% [markdown]
# # Radiomics re-extraction (5-notebook parallel runner)
#
# Duplicate this notebook **5 times**. In each copy, edit only the **shard cell** below
# (uncomment your shard index). Run order:
#
# 1. Run the **smoke test** once, in a single notebook, to confirm the pipeline.
# 2. Run **Step 1 (normalize)** in all 5 notebooks. Wait until all 5 finish.
# 3. Run **Step 2 (extract)** in all 5 notebooks. Wait until all 5 finish.
# 4. Run **Step 3 (combine)** once, in a single notebook.
#
# A notebook that times out can simply be rerun: finished cases are skipped.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Same environment your !python calls will use
# !pip install SimpleITK -q
# !pip install git+https://github.com/AIM-Harvard/pyradiomics@v3.1.0 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 21.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 5.9 MB/s eta 0:00:00
#   Building wheel for pyradiomics (pyproject.toml) ... done
#   Building wheel for docopt (setup.py) ... done

# %% [markdown]
# ## Shard cell  ← the ONLY thing you change per duplicated notebook
#
# Leave `NUM_SHARDS = 5`. Uncomment exactly one `SHARD_INDEX` line.

# %%
# --- Path to the folder where you pasted the three .py scripts ---
SCRIPT_DIR = '/content/drive/MyDrive/bsd/11_radiomics_for_gliomas/02_train/trial_80/notebooks'

# --- This notebook's shard. Uncomment exactly ONE line. ---
NUM_SHARDS = 5
# SHARD_INDEX = 0
# SHARD_INDEX = 1
# SHARD_INDEX = 2
SHARD_INDEX = 3
# SHARD_INDEX = 4

import os
NORMALIZE_SCRIPT = os.path.join(SCRIPT_DIR, '04_normalize_images.py')
EXTRACT_SCRIPT   = os.path.join(SCRIPT_DIR, '05_extract_wt_radiomics.py')
COMBINE_SCRIPT   = os.path.join(SCRIPT_DIR, '06_combine_features.py')

print(f"This notebook = shard {SHARD_INDEX} of {NUM_SHARDS}")
print(f"Scripts found:",
      os.path.exists(NORMALIZE_SCRIPT),
      os.path.exists(EXTRACT_SCRIPT),
      os.path.exists(COMBINE_SCRIPT))
# Out:
# This notebook = shard 3 of 5
# Scripts found: True True True

# %% [markdown]
# ## Smoke test (run ONCE, in a single notebook)
#
# No shard arguments = single-case test on BT0791. Normalizes that one case, then
# extracts it and prints the feature count. Confirms there is no GLCM hang before
# you commit all 5 machines.

# %%
# !python "{NORMALIZE_SCRIPT}"
# !python "{EXTRACT_SCRIPT}"
# Out:
# SMOKE TEST MODE: normalizing only BT0791
#
# Normalizing: BT0791
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Smoke test done.
# Fixed bin Count enabled! However, we recommend using a fixed bin Width. See http://pyradiomics.readthedocs.io/en/latest/faq.html#radiomics-fixed-bin-width for more details
# Extractor settings:
# {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binCount': 64}
#
# SMOKE TEST MODE: extracting only BT0791, nothing will be written.
#
# Extracting features for: BT0791
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> SMOKE TEST: 4224 features extracted (no hang).
#   -> sample keys: ['FLAIR_original_firstorder_10Percentile', 'FLAIR_original_firstorder_90Percentile', 'FLAIR_original_firstorder_Energy', 'FLAIR_original_firstorder_Entropy', 'FLAIR_original_firstorder_InterquartileRange']
#
# Smoke test done.

# %% [markdown]
# ## Step 1: Normalize (run in ALL 5 notebooks)
#
# Each notebook normalizes its own one-fifth of the cases. Wait for all 5 to finish
# before Step 2, because extraction reads the `_norm` files produced here.

# %%
# !python "{NORMALIZE_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Shard 3 of 5. Total case folders: 2061
#
# Normalizing: BT0005
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0013
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0021
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0029
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0036
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: brain mean 254.49, std 111.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0050
#   -> flair: brain mean 509.62, std 119.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1984.30, std 295.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1558.34, std 260.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1170.54, std 330.55 -> saved t2_norm.nii.gz
#
# Normalizing: BT0061
#   -> flair: brain mean 370.80, std 93.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 466.66, std 87.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 444.14, std 77.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 533.71, std 163.19 -> saved t2_norm.nii.gz
#
# Normalizing: BT0068
#   -> flair: brain mean 775.74, std 192.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1052.66, std 141.46 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2587.04, std 338.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 858.42, std 235.98 -> saved t2_norm.nii.gz
#
# Normalizing: BT0079
#   -> flair: brain mean 488.57, std 140.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 426.58, std 125.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 598.54, std 209.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 876.76, std 305.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT0087
#   -> flair: brain mean 249.05, std 76.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 888.63, std 184.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 564.64, std 112.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 667.69, std 221.38 -> saved t2_norm.nii.gz
#
# Normalizing: BT0096
#   -> flair: brain mean 649.17, std 148.95 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1044.97, std 183.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1018.85, std 144.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 713.66, std 259.44 -> saved t2_norm.nii.gz
#
# Normalizing: BT0104
#   -> flair: brain mean 787.45, std 183.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1143.94, std 164.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1043.93, std 170.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 824.41, std 256.46 -> saved t2_norm.nii.gz
#
# Normalizing: BT0115
#   -> flair: brain mean 663.38, std 141.48 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1227.54, std 185.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 893.92, std 159.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 832.13, std 246.30 -> saved t2_norm.nii.gz
#
# Normalizing: BT0126
#   -> flair: brain mean 397.41, std 104.93 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 862.62, std 249.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 564.45, std 122.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 590.19, std 287.41 -> saved t2_norm.nii.gz
#
# Normalizing: BT0133
#   -> flair: brain mean 403.10, std 114.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1272.89, std 175.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1037.54, std 151.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 679.22, std 260.46 -> saved t2_norm.nii.gz
#
# Normalizing: BT0140
#   -> flair: brain mean 415.74, std 104.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 583.33, std 96.94 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 630.43, std 110.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 451.69, std 150.08 -> saved t2_norm.nii.gz
#
# Normalizing: BT0145
#   -> flair: brain mean 237.86, std 78.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 877.83, std 239.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 712.97, std 225.09 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1154.72, std 412.25 -> saved t2_norm.nii.gz
#
# Normalizing: BT0150
#   -> flair: brain mean 680.25, std 133.65 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 669.93, std 86.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 638.45, std 104.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 175.48, std 48.28 -> saved t2_norm.nii.gz
#
# Normalizing: BT0158
#   -> flair: brain mean 637.46, std 154.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1385.86, std 203.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1427.64, std 233.81 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1453.38, std 456.21 -> saved t2_norm.nii.gz
#
# Normalizing: BT0166
#   -> flair: brain mean 398.03, std 61.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1379.83, std 217.79 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1206.71, std 217.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 677.02, std 121.24 -> saved t2_norm.nii.gz
#
# Normalizing: BT0173
#   -> flair: brain mean 193.74, std 43.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 895.33, std 112.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 804.56, std 115.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 435.82, std 155.63 -> saved t2_norm.nii.gz
#
# Normalizing: BT0184
#   -> flair: brain mean 330.76, std 83.70 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 545.39, std 83.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 441.94, std 81.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 404.92, std 122.47 -> saved t2_norm.nii.gz
#
# Normalizing: BT0191
#   -> flair: brain mean 168.40, std 33.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 391.66, std 56.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 383.49, std 61.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 312.68, std 99.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT0199
#   -> flair: brain mean 227.28, std 65.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1272.16, std 162.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 308.83, std 81.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 551.69, std 280.53 -> saved t2_norm.nii.gz
#
# Normalizing: BT0211
#   -> flair: brain mean 217.32, std 56.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1471.00, std 172.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 302.35, std 70.34 -> saved t1_norm.nii.gz
#   -> t2: brain mean 485.75, std 226.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT0220
#   -> flair: brain mean 274.30, std 72.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 423.57, std 83.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 565.04, std 112.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 403.79, std 175.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT0225
#   -> flair: brain mean 4182.32, std 1206.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 356.36, std 56.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3313.87, std 846.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 173.79, std 57.47 -> saved t2_norm.nii.gz
#
# Normalizing: BT0234
#   -> flair: brain mean 238.23, std 63.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 624.08, std 105.79 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 604.21, std 94.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 363.56, std 116.03 -> saved t2_norm.nii.gz
#
# Normalizing: BT0242
#   -> flair: brain mean 233.06, std 57.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 506.35, std 78.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 511.97, std 89.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 341.60, std 134.35 -> saved t2_norm.nii.gz
#
# Normalizing: BT0250
#   -> flair: brain mean 281.82, std 60.98 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 693.28, std 93.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 759.86, std 109.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 411.26, std 149.32 -> saved t2_norm.nii.gz
#
# Normalizing: BT0258
#   -> flair: brain mean 535.80, std 145.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2714.41, std 765.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 601.20, std 128.58 -> saved t1_norm.nii.gz
#   -> t2: brain mean 232.59, std 85.74 -> saved t2_norm.nii.gz
#
# Normalizing: BT0270
#   -> flair: brain mean 438.59, std 98.65 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 512.80, std 89.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 655.74, std 124.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 491.13, std 329.53 -> saved t2_norm.nii.gz
#
# Normalizing: BT0280
#   -> flair: brain mean 289.73, std 75.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 737.13, std 134.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 691.31, std 129.18 -> saved t1_norm.nii.gz
#   -> t2: brain mean 619.22, std 206.72 -> saved t2_norm.nii.gz
#
# Normalizing: BT0287
#   -> flair: brain mean 379.90, std 122.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 973.77, std 191.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1020.62, std 207.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 525.50, std 252.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT0294
#   -> flair: brain mean 329.78, std 101.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 695.69, std 132.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 618.50, std 97.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 415.36, std 120.89 -> saved t2_norm.nii.gz
#
# Normalizing: BT0301
#   -> flair: brain mean 678.23, std 165.33 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 42046.55, std 7989.18 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1716.79, std 494.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1907.96, std 765.71 -> saved t2_norm.nii.gz
#
# Normalizing: BT0310
#   -> flair: brain mean 265.22, std 73.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 627.18, std 48.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 422.34, std 51.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 551.65, std 65.35 -> saved t2_norm.nii.gz
#
# Normalizing: BT0319
#   -> flair: brain mean 468.93, std 112.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 675.68, std 202.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 624.80, std 182.97 -> saved t1_norm.nii.gz
#   -> t2: brain mean 817.29, std 192.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT0327
#   -> flair: brain mean 634.00, std 141.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1938.04, std 385.59 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1765.72, std 405.97 -> saved t1_norm.nii.gz
#   -> t2: brain mean 752.11, std 152.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT0339
#   -> flair: brain mean 394.86, std 89.88 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 652.16, std 132.94 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 624.14, std 100.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 595.13, std 239.17 -> saved t2_norm.nii.gz
#
# Normalizing: BT0351
#   -> flair: brain mean 647.20, std 193.81 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 858.87, std 163.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 934.73, std 204.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 897.57, std 304.69 -> saved t2_norm.nii.gz
#
# Normalizing: BT0363
#   -> flair: brain mean 418.53, std 100.93 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 835.43, std 134.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 961.31, std 175.35 -> saved t1_norm.nii.gz
#   -> t2: brain mean 444.97, std 168.02 -> saved t2_norm.nii.gz
#
# Normalizing: BT0373
#   -> flair: brain mean 387.61, std 89.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 639.48, std 102.87 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 544.08, std 100.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 420.51, std 176.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0384
#   -> flair: brain mean 7981.49, std 1737.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 14152.89, std 3028.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 13558.76, std 3344.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 16322.40, std 3688.86 -> saved t2_norm.nii.gz
#
# Normalizing: BT0398
#   -> flair: brain mean 401.05, std 96.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 567.14, std 86.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 594.11, std 103.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 484.49, std 176.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT0407
#   -> flair: brain mean 331.04, std 74.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 441.76, std 56.93 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 432.90, std 63.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 342.08, std 95.51 -> saved t2_norm.nii.gz
#
# Normalizing: BT0416
#   -> flair: brain mean 705.63, std 144.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 918.54, std 144.30 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1109.58, std 189.49 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1214.69, std 250.85 -> saved t2_norm.nii.gz
#
# Normalizing: BT0426
#   -> flair: brain mean 426.14, std 120.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 367.86, std 90.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 479.69, std 96.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 556.20, std 214.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT0438
#   -> flair: brain mean 480.50, std 160.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 880.16, std 154.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 952.58, std 190.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 801.82, std 413.75 -> saved t2_norm.nii.gz
#
# Normalizing: BT0456
#   -> flair: brain mean 363.18, std 97.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 438.93, std 73.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 390.30, std 67.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 455.48, std 109.25 -> saved t2_norm.nii.gz
#
# Normalizing: BT0465
#   -> flair: brain mean 15879.77, std 4500.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 32902.45, std 5902.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 32396.50, std 6145.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 9941.47, std 3033.04 -> saved t2_norm.nii.gz
#
# Normalizing: BT0474
#   -> flair: brain mean 571.58, std 131.41 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2179.85, std 457.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1482.52, std 252.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 902.67, std 261.24 -> saved t2_norm.nii.gz
#
# Normalizing: BT0486
#   -> flair: brain mean 277.09, std 76.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 756.39, std 197.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 605.15, std 173.99 -> saved t1_norm.nii.gz
#   -> t2: brain mean 418.12, std 166.55 -> saved t2_norm.nii.gz
#
# Normalizing: BT0498
#   -> flair: brain mean 1131.05, std 298.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3436.61, std 781.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1607.35, std 286.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1912.06, std 908.68 -> saved t2_norm.nii.gz
#
# Normalizing: BT0521
#   -> flair: brain mean 558.41, std 132.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 535.67, std 168.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 494.78, std 170.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 888.08, std 346.49 -> saved t2_norm.nii.gz
#
# Normalizing: BT0600
#   -> flair: brain mean 317.57, std 65.93 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1398.10, std 151.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 490.13, std 119.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 469.35, std 149.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0610
#   -> flair: brain mean 407.05, std 95.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 647.40, std 153.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 656.91, std 179.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 636.34, std 171.29 -> saved t2_norm.nii.gz
#
# Normalizing: BT0617
#   -> flair: brain mean 467.43, std 126.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 476.55, std 139.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 604.51, std 96.58 -> saved t1_norm.nii.gz
#   -> t2: brain mean 592.97, std 195.58 -> saved t2_norm.nii.gz
#
# Normalizing: BT0623
#   -> flair: brain mean 352.03, std 87.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 425.29, std 56.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 492.78, std 77.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 421.09, std 137.17 -> saved t2_norm.nii.gz
#
# Normalizing: BT0630
#   -> flair: brain mean 304.45, std 103.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 557.70, std 105.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 475.26, std 90.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 495.02, std 159.81 -> saved t2_norm.nii.gz
#
# Normalizing: BT0636
#   -> flair: brain mean 140.70, std 38.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 643.30, std 94.50 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 664.10, std 105.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 355.57, std 185.57 -> saved t2_norm.nii.gz
#
# Normalizing: BT0643
#   -> flair: brain mean 588.67, std 129.04 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1745.90, std 258.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1660.49, std 280.31 -> saved t1_norm.nii.gz
#   -> t2: brain mean 842.03, std 289.35 -> saved t2_norm.nii.gz
#
# Normalizing: BT0652
#   -> flair: brain mean 152.52, std 40.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 285.18, std 52.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 296.64, std 58.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 289.88, std 136.32 -> saved t2_norm.nii.gz
#
# Normalizing: BT0660
#   -> flair: brain mean 188.47, std 41.48 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 232.92, std 39.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 210.76, std 33.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 187.96, std 40.44 -> saved t2_norm.nii.gz
#
# Normalizing: BT0670
#   -> flair: brain mean 353.01, std 103.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1046.62, std 171.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1173.84, std 200.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 388.62, std 160.38 -> saved t2_norm.nii.gz
#
# Normalizing: BT0678
#   -> flair: brain mean 458.27, std 122.98 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 923.40, std 137.01 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1005.45, std 156.40 -> saved t1_norm.nii.gz
#   -> t2: brain mean 484.34, std 127.62 -> saved t2_norm.nii.gz
#
# Normalizing: BT0687
#   -> flair: brain mean 5706.58, std 1442.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 21708.07, std 4236.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 19800.90, std 5182.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2727.60, std 1051.95 -> saved t2_norm.nii.gz
#
# Normalizing: BT0695
#   -> flair: brain mean 182.65, std 44.03 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 541.54, std 91.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 484.82, std 94.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 657.91, std 211.85 -> saved t2_norm.nii.gz
#
# Normalizing: BT0709
#   -> flair: brain mean 1033.08, std 217.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 935.56, std 221.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 624.54, std 181.23 -> saved t1_norm.nii.gz
#   -> t2: brain mean 793.41, std 216.59 -> saved t2_norm.nii.gz
#
# Normalizing: BT0719
#   -> flair: brain mean 394.95, std 106.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 408.30, std 94.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 510.80, std 92.27 -> saved t1_norm.nii.gz
#   -> t2: brain mean 493.07, std 154.92 -> saved t2_norm.nii.gz
#
# Normalizing: BT0728
#   -> flair: brain mean 541.97, std 143.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2759.94, std 745.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1204.30, std 196.09 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1168.21, std 545.50 -> saved t2_norm.nii.gz
#
# Normalizing: BT0735
#   -> flair: brain mean 437.06, std 102.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 448.02, std 85.81 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 438.12, std 96.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 425.97, std 127.14 -> saved t2_norm.nii.gz
#
# Normalizing: BT0742
#   -> flair: brain mean 153.33, std 47.85 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 263.71, std 51.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 234.13, std 44.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 266.24, std 122.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT0750
#   -> flair: brain mean 356.28, std 93.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 607.72, std 126.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1152.14, std 160.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 475.74, std 183.18 -> saved t2_norm.nii.gz
#
# Normalizing: BT0756
#   -> flair: brain mean 458.02, std 132.12 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1144.15, std 206.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1020.97, std 163.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 975.99, std 395.27 -> saved t2_norm.nii.gz
#
# Normalizing: BT0765
#   -> flair: brain mean 251.96, std 72.41 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1494.74, std 228.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1014.71, std 174.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 630.90, std 288.41 -> saved t2_norm.nii.gz
#
# Normalizing: BT0770
#   -> flair: brain mean 180.41, std 39.48 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 406.23, std 54.67 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 422.73, std 68.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 303.86, std 105.30 -> saved t2_norm.nii.gz
#
# Normalizing: BT0782
#   -> flair: brain mean 175.10, std 61.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 377.14, std 78.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 319.62, std 69.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 361.91, std 113.21 -> saved t2_norm.nii.gz
#
# Normalizing: BT0787
#   -> flair: brain mean 574.37, std 149.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 582.05, std 109.94 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 564.74, std 91.52 -> saved t1_norm.nii.gz
#   -> t2: brain mean 657.63, std 181.39 -> saved t2_norm.nii.gz
#
# Normalizing: BT0794
#   -> flair: brain mean 354.47, std 91.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 594.59, std 76.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 601.66, std 86.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 538.23, std 153.62 -> saved t2_norm.nii.gz
#
# Normalizing: BT0805
#   -> flair: brain mean 909.55, std 290.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 863.40, std 169.35 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 927.76, std 142.83 -> saved t1_norm.nii.gz
#   -> t2: brain mean 692.59, std 260.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT0817
#   -> flair: brain mean 565.38, std 130.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3478.43, std 318.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 817.01, std 227.27 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1178.15, std 593.15 -> saved t2_norm.nii.gz
#
# Normalizing: BT0829
#   -> flair: brain mean 432.24, std 131.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 630.22, std 166.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1169.42, std 143.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 492.40, std 341.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT0837
#   -> flair: brain mean 948.37, std 239.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 895.69, std 115.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1027.28, std 133.76 -> saved t1_norm.nii.gz
#   -> t2: brain mean 795.52, std 262.25 -> saved t2_norm.nii.gz
#
# Normalizing: BT0847
#   -> flair: brain mean 1200.99, std 307.48 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 742.12, std 144.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 845.01, std 186.41 -> saved t1_norm.nii.gz
#   -> t2: brain mean 699.61, std 146.49 -> saved t2_norm.nii.gz
#
# Normalizing: BT0907
#   -> flair: brain mean 220.00, std 53.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 305.68, std 62.60 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 454.05, std 55.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 318.52, std 107.26 -> saved t2_norm.nii.gz
#
# Normalizing: BT0917
#   -> flair: brain mean 483.24, std 117.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1240.62, std 198.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1105.57, std 190.62 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1060.42, std 433.63 -> saved t2_norm.nii.gz
#
# Normalizing: BT0929
#   -> flair: brain mean 325.75, std 92.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1145.49, std 179.67 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1067.60, std 179.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 456.27, std 195.99 -> saved t2_norm.nii.gz
#
# Normalizing: BT0945
#   -> flair: brain mean 310.13, std 93.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 546.84, std 113.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 845.41, std 134.35 -> saved t1_norm.nii.gz
#   -> t2: brain mean 508.98, std 233.81 -> saved t2_norm.nii.gz
#
# Normalizing: BT0953
#   -> flair: brain mean 1671.22, std 372.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1039.00, std 221.60 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1236.16, std 278.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 619.17, std 215.38 -> saved t2_norm.nii.gz
#
# Normalizing: BT0960
#   -> flair: brain mean 356.44, std 95.91 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 589.14, std 101.46 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 520.66, std 99.11 -> saved t1_norm.nii.gz
#   -> t2: brain mean 488.70, std 227.79 -> saved t2_norm.nii.gz
#
# Normalizing: BT0969
#   -> flair: brain mean 1070.03, std 271.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 913.44, std 216.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 862.23, std 222.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 877.34, std 222.80 -> saved t2_norm.nii.gz
#
# Normalizing: BT1001
#   -> flair: brain mean 224.24, std 63.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 418.13, std 80.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 424.96, std 86.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 382.62, std 152.12 -> saved t2_norm.nii.gz
#
# Normalizing: BT1012
#   -> flair: brain mean 476.36, std 89.81 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 954.42, std 383.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 955.72, std 153.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 526.98, std 142.46 -> saved t2_norm.nii.gz
#
# Normalizing: BT1019
#   -> flair: brain mean 860.24, std 203.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 677.19, std 218.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 872.32, std 166.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 744.63, std 193.45 -> saved t2_norm.nii.gz
#
# Normalizing: BT1026
#   -> flair: brain mean 400.69, std 97.51 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 447.08, std 127.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 504.85, std 130.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 662.73, std 193.54 -> saved t2_norm.nii.gz
#
# Normalizing: BT1033
#   -> flair: brain mean 613.29, std 168.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 806.70, std 164.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 780.02, std 139.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 967.10, std 349.27 -> saved t2_norm.nii.gz
#
# Normalizing: BT1038
#   -> flair: brain mean 121.16, std 31.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 239.64, std 41.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 231.95, std 43.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 208.02, std 85.54 -> saved t2_norm.nii.gz
#
# Normalizing: BT1048
#   -> flair: brain mean 412.25, std 124.33 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 490.40, std 107.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 521.44, std 91.40 -> saved t1_norm.nii.gz
#   -> t2: brain mean 491.14, std 200.62 -> saved t2_norm.nii.gz
#
# Normalizing: BT1056
#   -> flair: brain mean 864.36, std 151.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1691.39, std 173.60 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1590.84, std 277.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1022.94, std 304.39 -> saved t2_norm.nii.gz
#
# Normalizing: BT1070
#   -> flair: brain mean 377.58, std 69.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1173.80, std 323.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 765.44, std 113.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 528.28, std 139.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT1079
#   -> flair: brain mean 976.73, std 240.65 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1339.95, std 337.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1071.74, std 158.37 -> saved t1_norm.nii.gz
#   -> t2: brain mean 765.35, std 239.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT1084
#   -> flair: brain mean 612.34, std 155.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 944.98, std 154.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1239.70, std 190.83 -> saved t1_norm.nii.gz
#   -> t2: brain mean 747.33, std 300.32 -> saved t2_norm.nii.gz
#
# Normalizing: BT1090
#   -> flair: brain mean 499.68, std 124.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2491.72, std 398.53 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 681.43, std 259.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1160.90, std 675.10 -> saved t2_norm.nii.gz
#
# Normalizing: BT1096
#   -> flair: brain mean 252.10, std 59.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 922.04, std 119.55 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 339.46, std 85.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 359.56, std 168.90 -> saved t2_norm.nii.gz
#
# Normalizing: BT1103
#   -> flair: brain mean 387.98, std 121.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 731.00, std 120.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 712.67, std 112.07 -> saved t1_norm.nii.gz
#   -> t2: brain mean 704.18, std 191.82 -> saved t2_norm.nii.gz
#
# Normalizing: BT1108
#   -> flair: brain mean 1131.04, std 330.70 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 649.24, std 189.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 719.69, std 232.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 912.99, std 228.14 -> saved t2_norm.nii.gz
#
# Normalizing: BT1114
#   -> flair: brain mean 420.42, std 114.66 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 700.34, std 117.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 774.09, std 127.91 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1053.51, std 511.45 -> saved t2_norm.nii.gz
#
# Normalizing: BT1121
#   -> flair: brain mean 1314.16, std 520.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1088.64, std 205.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1098.03, std 198.70 -> saved t1_norm.nii.gz
#   -> t2: brain mean 611.14, std 230.58 -> saved t2_norm.nii.gz
#
# Normalizing: BT1126
#   -> flair: brain mean 672.75, std 132.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 944.00, std 135.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 952.41, std 143.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 866.54, std 244.76 -> saved t2_norm.nii.gz
#
# Normalizing: BT1135
#   -> flair: brain mean 587.32, std 108.24 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 835.07, std 121.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 825.89, std 128.07 -> saved t1_norm.nii.gz
#   -> t2: brain mean 893.77, std 282.21 -> saved t2_norm.nii.gz
#
# Normalizing: BT1141
#   -> flair: brain mean 325.38, std 70.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 721.52, std 103.46 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 800.97, std 131.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 400.18, std 160.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT1150
#   -> flair: brain mean 417.15, std 88.21 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 492.65, std 109.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 507.03, std 83.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 463.20, std 155.31 -> saved t2_norm.nii.gz
#
# Normalizing: BT1208
#   -> flair: brain mean 213.82, std 46.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 688.37, std 66.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 368.33, std 65.86 -> saved t1_norm.nii.gz
#   -> t2: brain mean 267.93, std 95.81 -> saved t2_norm.nii.gz
#
# Normalizing: BT1223
#   -> flair: brain mean 327.95, std 96.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 844.22, std 134.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 618.17, std 120.27 -> saved t1_norm.nii.gz
#   -> t2: brain mean 817.03, std 378.50 -> saved t2_norm.nii.gz
#
# Normalizing: BT1233
#   -> flair: brain mean 193.89, std 59.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 418.03, std 114.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 806.82, std 151.20 -> saved t1_norm.nii.gz
#   -> t2: brain mean 590.77, std 200.88 -> saved t2_norm.nii.gz
#
# Normalizing: BT1240
#   -> flair: brain mean 1277.49, std 375.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 571.05, std 171.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 733.92, std 198.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 853.54, std 246.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT1247
#   -> flair: brain mean 1222.37, std 318.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 892.47, std 174.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1259.41, std 144.51 -> saved t1_norm.nii.gz
#   -> t2: brain mean 630.01, std 220.87 -> saved t2_norm.nii.gz
#
# Normalizing: BT1254
#   -> flair: brain mean 409.85, std 100.69 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1509.13, std 425.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 632.08, std 173.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 705.10, std 201.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT1267
#   -> flair: brain mean 892.14, std 294.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 728.15, std 222.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 837.58, std 229.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 893.74, std 266.23 -> saved t2_norm.nii.gz
#
# Normalizing: BT1272
#   -> flair: brain mean 435.00, std 91.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1553.95, std 165.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 745.67, std 205.99 -> saved t1_norm.nii.gz
#   -> t2: brain mean 790.03, std 326.71 -> saved t2_norm.nii.gz
#
# Normalizing: BT1279
#   -> flair: brain mean 223.38, std 55.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 382.46, std 106.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 346.96, std 104.87 -> saved t1_norm.nii.gz
#   -> t2: brain mean 230.86, std 135.68 -> saved t2_norm.nii.gz
#
# Normalizing: BT1285
#   -> flair: brain mean 148.65, std 40.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 563.00, std 93.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 244.54, std 46.03 -> saved t1_norm.nii.gz
#   -> t2: brain mean 254.36, std 96.51 -> saved t2_norm.nii.gz
#
# Normalizing: BT1297
#   -> flair: brain mean 286.35, std 78.37 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1051.30, std 182.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 985.27, std 167.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 464.48, std 217.04 -> saved t2_norm.nii.gz
#
# Normalizing: BT1311
#   -> flair: brain mean 396.99, std 82.57 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 621.60, std 157.56 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 586.82, std 151.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 577.09, std 150.83 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0004
#   -> flair: brain mean 230.66, std 60.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 350.89, std 74.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 258.44, std 59.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 325.75, std 118.17 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0009
#   -> flair: brain mean 597.69, std 200.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 637.05, std 161.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 629.57, std 168.23 -> saved t1_norm.nii.gz
#   -> t2: brain mean 831.26, std 370.45 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0014
#   -> flair: brain mean 1102.75, std 411.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1613.03, std 598.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 973.04, std 166.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 843.13, std 478.38 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0019
#   -> flair: brain mean 476.70, std 126.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 474.34, std 164.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1303.47, std 371.99 -> saved t1_norm.nii.gz
#   -> t2: brain mean 639.26, std 274.17 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0024
#   -> flair: brain mean 286.83, std 91.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 293.55, std 65.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 318.56, std 68.81 -> saved t1_norm.nii.gz
#   -> t2: brain mean 415.18, std 173.98 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0029
#   -> flair: brain mean 251.15, std 61.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 322.22, std 55.75 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 298.77, std 63.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 280.01, std 103.28 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0034
#   -> flair: brain mean 831.25, std 331.93 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 563.13, std 221.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 266.62, std 119.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 854.70, std 268.55 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0039
#   -> flair: brain mean 176.06, std 59.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 102.40, std 23.25 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 299.73, std 66.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 258.62, std 96.35 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0044
#   -> flair: brain mean 903.75, std 332.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 822.07, std 157.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 606.28, std 109.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 953.20, std 409.86 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0049
#   -> flair: brain mean 272.25, std 62.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 167.04, std 39.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 179.56, std 38.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 306.72, std 61.49 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0054
#   -> flair: brain mean 187.43, std 62.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 249.78, std 55.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 251.89, std 55.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 308.13, std 113.15 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0059
#   -> flair: brain mean 431.17, std 157.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 300.01, std 117.29 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 318.09, std 116.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 663.36, std 342.40 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0064
#   -> flair: brain mean 1294.70, std 432.46 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2008.69, std 759.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1036.79, std 227.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 893.28, std 449.01 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0069
#   -> flair: brain mean 132.73, std 35.19 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 70.87, std 35.94 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 257.07, std 51.09 -> saved t1_norm.nii.gz
#   -> t2: brain mean 223.54, std 79.26 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0074
#   -> flair: brain mean 72.05, std 23.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 167.61, std 46.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 201.78, std 56.03 -> saved t1_norm.nii.gz
#   -> t2: brain mean 142.22, std 35.58 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0079
#   -> flair: brain mean 164.08, std 38.77 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 248.04, std 32.81 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 191.83, std 29.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 183.41, std 44.45 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0084
#   -> flair: brain mean 365.88, std 129.92 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 368.70, std 118.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 477.93, std 86.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 555.33, std 264.75 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0089
#   -> flair: brain mean 720.15, std 241.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1104.72, std 474.30 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 761.09, std 147.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 548.97, std 335.53 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0094
#   -> flair: brain mean 1031.64, std 350.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 668.15, std 211.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1131.01, std 339.91 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1532.83, std 443.76 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0099
#   -> flair: brain mean 893.97, std 344.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4218.17, std 1212.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3191.49, std 535.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2380.76, std 1217.48 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0104
#   -> flair: brain mean 367.02, std 96.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 588.28, std 100.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 447.00, std 84.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 491.33, std 144.96 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0109
#   -> flair: brain mean 1138.54, std 343.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1855.20, std 680.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1477.50, std 219.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 672.17, std 332.23 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0114
#   -> flair: brain mean 835.59, std 222.66 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 849.38, std 155.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 808.12, std 140.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 401.31, std 179.06 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0119
#   -> flair: brain mean 604.74, std 177.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 603.25, std 208.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 607.95, std 146.07 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1267.25, std 280.62 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0124
#   -> flair: brain mean 332.86, std 92.15 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 451.16, std 85.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1188.46, std 141.35 -> saved t1_norm.nii.gz
#   -> t2: brain mean 389.38, std 171.66 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0129
#   -> flair: brain mean 225.89, std 59.35 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 470.75, std 98.59 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 286.53, std 60.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 362.39, std 167.78 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0134
#   -> flair: brain mean 283.30, std 84.33 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 128.81, std 41.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 275.23, std 56.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 296.71, std 54.60 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0139
#   -> flair: brain mean 219.30, std 83.92 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 365.79, std 89.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 292.08, std 97.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 307.51, std 60.43 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0144
#   -> flair: brain mean 1447.96, std 582.39 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2043.77, std 875.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1547.35, std 524.56 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1435.84, std 778.75 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0149
#   -> flair: brain mean 1084.67, std 505.98 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2458.18, std 1086.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2335.29, std 302.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2052.73, std 839.97 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0154
#   -> flair: brain mean 716.24, std 245.46 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 683.11, std 244.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 651.45, std 175.07 -> saved t1_norm.nii.gz
#   -> t2: brain mean 878.02, std 365.82 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0159
#   -> flair: brain mean 591.58, std 194.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1000.43, std 378.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 946.53, std 182.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 580.71, std 327.01 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0164
#   -> flair: brain mean 486.09, std 170.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3710.56, std 1149.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3234.28, std 780.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1870.66, std 947.37 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0169
#   -> flair: brain mean 283.15, std 73.87 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 851.63, std 162.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 637.61, std 133.83 -> saved t1_norm.nii.gz
#   -> t2: brain mean 427.04, std 138.43 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0174
#   -> flair: brain mean 260.86, std 87.70 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 111.75, std 37.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 201.05, std 48.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 374.08, std 136.91 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0179
#   -> flair: brain mean 372.34, std 72.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 478.81, std 70.33 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 417.05, std 72.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 275.84, std 54.25 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0184
#   -> flair: brain mean 760.76, std 231.95 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 584.03, std 134.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 541.80, std 155.94 -> saved t1_norm.nii.gz
#   -> t2: brain mean 426.45, std 227.28 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0189
#   -> flair: brain mean 916.58, std 359.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 624.71, std 234.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 812.96, std 270.98 -> saved t1_norm.nii.gz
#   -> t2: brain mean 917.56, std 374.47 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0194
#   -> flair: brain mean 285.70, std 73.37 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 444.09, std 75.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 430.72, std 79.23 -> saved t1_norm.nii.gz
#   -> t2: brain mean 320.19, std 117.83 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0199
#   -> flair: brain mean 1700.51, std 421.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3885.73, std 1216.16 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3198.56, std 649.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1330.05, std 671.38 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0204
#   -> flair: brain mean 1014.43, std 407.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 584.62, std 195.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 421.11, std 182.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1785.89, std 564.49 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0209
#   -> flair: brain mean 124.55, std 40.61 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 328.47, std 79.06 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 273.10, std 75.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 228.48, std 81.26 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0214
#   -> flair: brain mean 280.13, std 61.91 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 508.95, std 85.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 345.55, std 59.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 302.02, std 103.49 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0219
#   -> flair: brain mean 344.12, std 101.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 433.98, std 72.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 389.91, std 72.67 -> saved t1_norm.nii.gz
#   -> t2: brain mean 343.41, std 70.43 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0224
#   -> flair: brain mean 785.23, std 269.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 682.92, std 230.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 636.52, std 194.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 508.28, std 242.48 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0229
#   -> flair: brain mean 803.80, std 266.09 -> saved flair_norm.nii.gz
# ...
#
# Normalizing: UCSF-PDGM-0268_nifti
#   -> flair: brain mean 961.58, std 300.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3300.74, std 999.01 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2952.62, std 842.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 563.77, std 270.84 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0274_nifti
#   -> flair: brain mean 1073.18, std 384.21 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4149.23, std 1158.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3050.66, std 905.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 455.18, std 218.30 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0280_nifti
#   -> flair: brain mean 1589.97, std 540.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4421.57, std 1368.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3815.17, std 973.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 552.18, std 218.53 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0285_nifti
#   -> flair: brain mean 1275.70, std 435.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3567.16, std 908.89 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3201.36, std 906.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 555.61, std 263.52 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0291_nifti
#   -> flair: brain mean 694.42, std 243.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3717.03, std 1078.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3192.19, std 843.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 749.14, std 326.41 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0300_nifti
#   -> flair: brain mean 1198.01, std 407.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3187.61, std 923.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2661.82, std 813.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 674.06, std 343.67 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0306_nifti
#   -> flair: brain mean 882.80, std 297.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3846.96, std 1319.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1213.48, std 208.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 615.83, std 251.02 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0311_nifti
#   -> flair: brain mean 1209.89, std 395.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4378.57, std 1318.41 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3165.85, std 859.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 318.58, std 208.09 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0317_nifti
#   -> flair: brain mean 945.79, std 327.67 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3156.74, std 1009.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2958.00, std 853.85 -> saved t1_norm.nii.gz
#   -> t2: brain mean 710.95, std 394.94 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0323_nifti
#   -> flair: brain mean 1224.27, std 464.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4764.89, std 1621.67 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3824.28, std 1078.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 691.31, std 379.52 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0328_nifti
#   -> flair: brain mean 794.83, std 302.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5278.97, std 1320.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 5191.32, std 1051.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 568.71, std 389.48 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0333_nifti
#   -> flair: brain mean 1135.00, std 347.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3147.03, std 1115.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2952.40, std 813.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 663.89, std 375.17 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0338_nifti
#   -> flair: brain mean 1424.37, std 541.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2861.43, std 1004.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1237.22, std 210.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 752.56, std 407.68 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0343_nifti
#   -> flair: brain mean 1326.40, std 466.35 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3925.55, std 1570.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1693.51, std 306.13 -> saved t1_norm.nii.gz
#   -> t2: brain mean 667.50, std 425.72 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0348_nifti
#   -> flair: brain mean 931.18, std 334.46 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4518.25, std 1488.30 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3849.86, std 1224.27 -> saved t1_norm.nii.gz
#   -> t2: brain mean 454.09, std 202.52 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0353_nifti
#   -> flair: brain mean 965.99, std 310.46 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5017.25, std 1379.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3852.21, std 1073.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 401.22, std 158.35 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0358_nifti
#   -> flair: brain mean 717.46, std 221.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3727.93, std 1049.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3742.61, std 857.31 -> saved t1_norm.nii.gz
#   -> t2: brain mean 585.31, std 234.85 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0363_nifti
#   -> flair: brain mean 1110.98, std 391.65 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3385.82, std 1077.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2862.69, std 781.97 -> saved t1_norm.nii.gz
#   -> t2: brain mean 687.42, std 374.86 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0368_nifti
#   -> flair: brain mean 973.05, std 333.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4351.90, std 1192.86 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3785.33, std 1022.11 -> saved t1_norm.nii.gz
#   -> t2: brain mean 505.94, std 297.41 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0373_nifti
#   -> flair: brain mean 972.04, std 473.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3168.51, std 1254.71 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2385.73, std 919.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 730.13, std 387.03 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0378_nifti
#   -> flair: brain mean 1020.41, std 373.27 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3164.29, std 1215.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1789.93, std 361.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 842.31, std 482.07 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0383_nifti
#   -> flair: brain mean 1067.65, std 440.38 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1431.09, std 368.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1150.25, std 350.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 819.33, std 582.02 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0388_nifti
#   -> flair: brain mean 1009.55, std 351.03 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3163.61, std 942.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2655.99, std 723.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 593.40, std 335.87 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0393_nifti
#   -> flair: brain mean 970.83, std 378.21 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4419.36, std 1457.48 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3209.43, std 996.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 867.24, std 512.20 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0398_nifti
#   -> flair: brain mean 980.26, std 334.57 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3299.04, std 1029.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2618.06, std 773.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 682.35, std 298.81 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0403_nifti
#   -> flair: brain mean 852.97, std 294.15 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4313.19, std 1164.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3399.50, std 904.90 -> saved t1_norm.nii.gz
#   -> t2: brain mean 548.24, std 246.34 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0409_nifti
#   -> flair: brain mean 1152.44, std 392.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5090.69, std 1568.33 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3788.42, std 923.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 421.42, std 178.57 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0414_nifti
#   -> flair: brain mean 1021.74, std 368.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4279.07, std 1271.41 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3610.63, std 994.93 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1774.95, std 670.96 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0419_nifti
#   -> flair: brain mean 951.56, std 346.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3522.86, std 1332.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2710.90, std 940.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 872.65, std 460.86 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0424_nifti
#   -> flair: brain mean 1076.36, std 351.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5907.74, std 1677.75 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4026.01, std 1188.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 706.58, std 330.56 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0429_nifti
#   -> flair: brain mean 1356.41, std 457.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2859.92, std 987.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1244.18, std 217.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 652.19, std 333.39 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0434_nifti
#   -> flair: brain mean 512.10, std 161.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1333.82, std 420.59 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1516.88, std 449.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 261.12, std 224.09 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0439_nifti
#   -> flair: brain mean 886.69, std 295.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4022.06, std 1114.82 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2935.93, std 840.18 -> saved t1_norm.nii.gz
#   -> t2: brain mean 470.04, std 253.25 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0444_nifti
#   -> flair: brain mean 1238.44, std 462.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3419.94, std 1104.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1458.78, std 254.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 709.74, std 395.80 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0449_nifti
#   -> flair: brain mean 787.72, std 268.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3676.51, std 1100.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3555.70, std 998.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 689.26, std 311.36 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0454_nifti
#   -> flair: brain mean 817.51, std 310.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2637.97, std 1052.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2587.13, std 740.63 -> saved t1_norm.nii.gz
#   -> t2: brain mean 602.59, std 277.56 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0459_nifti
#   -> flair: brain mean 955.04, std 343.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3973.34, std 1139.25 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3207.78, std 902.56 -> saved t1_norm.nii.gz
#   -> t2: brain mean 617.11, std 308.90 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0464_nifti
#   -> flair: brain mean 786.23, std 277.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3548.82, std 1106.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2911.73, std 874.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 887.13, std 402.46 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0469_nifti
#   -> flair: brain mean 1018.56, std 355.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4039.22, std 1031.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1756.89, std 304.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 721.30, std 329.01 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0474_nifti
#   -> flair: brain mean 1144.43, std 340.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3834.04, std 895.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3380.12, std 785.51 -> saved t1_norm.nii.gz
#   -> t2: brain mean 541.93, std 178.17 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0479_nifti
#   -> flair: brain mean 1230.50, std 469.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4360.60, std 1559.00 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3269.12, std 958.87 -> saved t1_norm.nii.gz
#   -> t2: brain mean 654.91, std 310.93 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0484_nifti
#   -> flair: brain mean 1053.89, std 355.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3114.07, std 931.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2897.48, std 843.07 -> saved t1_norm.nii.gz
#   -> t2: brain mean 661.90, std 375.30 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0489_nifti
#   -> flair: brain mean 1347.52, std 456.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3393.13, std 911.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3040.05, std 801.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 634.22, std 252.30 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0494_nifti
#   -> flair: brain mean 911.00, std 339.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3169.77, std 996.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2321.09, std 807.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 651.26, std 277.09 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0499_nifti
#   -> flair: brain mean 1277.66, std 508.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 7473.79, std 1774.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 6200.13, std 1307.45 -> saved t1_norm.nii.gz
#   -> t2: brain mean 807.14, std 342.02 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0504_nifti
#   -> flair: brain mean 1113.31, std 362.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4466.86, std 1436.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3305.89, std 926.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 527.38, std 205.23 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0509_nifti
#   -> flair: brain mean 905.19, std 292.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3797.02, std 1159.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3567.92, std 818.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 654.56, std 302.95 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0514_nifti
#   -> flair: brain mean 1144.29, std 364.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4230.99, std 1191.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3127.40, std 791.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 825.79, std 317.37 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0519_nifti
#   -> flair: brain mean 944.36, std 298.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2955.07, std 927.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2607.45, std 733.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 642.86, std 338.92 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0524_nifti
#   -> flair: brain mean 744.76, std 269.41 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2780.55, std 916.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2280.29, std 803.51 -> saved t1_norm.nii.gz
#   -> t2: brain mean 538.24, std 257.62 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0529_nifti
#   -> flair: brain mean 1210.20, std 437.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3981.65, std 1153.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2950.91, std 759.40 -> saved t1_norm.nii.gz
#   -> t2: brain mean 697.31, std 333.68 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0534_nifti
#   -> flair: brain mean 873.42, std 282.30 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3217.64, std 1076.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2718.87, std 740.28 -> saved t1_norm.nii.gz
#   -> t2: brain mean 588.87, std 291.39 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0539_nifti
#   -> flair: brain mean 916.06, std 322.08 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2644.33, std 842.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2573.04, std 757.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 701.84, std 363.39 -> saved t2_norm.nii.gz
#
# Shard 3 of 5 complete.

# %% [markdown]
# ## Step 2: Extract (run in ALL 5 notebooks, after Step 1 is fully done)
#
# Each notebook extracts its own one-fifth and writes one CSV per case into
# `features/per_case/`. Safe to run concurrently (no shared file).

# %%
# !python "{EXTRACT_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Streaming output truncated to the last 5000 lines.
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote TCGA-HT-8114.csv
# Extracting features for: UCSF-PDGM-0007_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0007_nifti.csv
# Extracting features for: UCSF-PDGM-0012_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0012_nifti.csv
# Extracting features for: UCSF-PDGM-0017_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0017_nifti.csv
# Extracting features for: UCSF-PDGM-0022_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0022_nifti.csv
# Extracting features for: UCSF-PDGM-0027_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0027_nifti.csv
# Extracting features for: UCSF-PDGM-0033_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0033_nifti.csv
# Extracting features for: UCSF-PDGM-0038_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0038_nifti.csv
# Extracting features for: UCSF-PDGM-0043_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0043_nifti.csv
# Extracting features for: UCSF-PDGM-0048_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0048_nifti.csv
# Extracting features for: UCSF-PDGM-0056_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0524_nifti.csv
# Extracting features for: UCSF-PDGM-0529_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0529_nifti.csv
# Extracting features for: UCSF-PDGM-0534_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0534_nifti.csv
# Extracting features for: UCSF-PDGM-0539_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0539_nifti.csv
#
# Shard 3 of 5 complete.

# %% [markdown]
# ## Step 3: Combine (run ONCE, in a single notebook, after all of Step 2 is done)
#
# Concatenates every per-case CSV into `all_radiomics_features.csv` and prints
# per-cohort counts plus any cases missing a sequence.

# %%
# !python "{COMBINE_SCRIPT}"
