# %% [markdown]
# # Radiomics re-extraction (5-notebook parallel runner)
#
# Duplicate this notebook **5 times**. In each copy, edit only the **shard cell** below
# (uncomment your shard index). Run order:
#
# 1. Run the **smoke test** once, in a single notebook, to confirm the pipeline.
# 2. Run **Step 1 (normalize)** in all 5 notebooks. Wait until all 5 finish.
# 3. Run **Step 2 (extract)** in all 5 notebooks. Wait until all 5 finish.
# 4. Run **Step 3 (combine)** once, in a single notebook.
#
# A notebook that times out can simply be rerun: finished cases are skipped.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Same environment your !python calls will use
# !pip install SimpleITK -q
# !pip install git+https://github.com/AIM-Harvard/pyradiomics@v3.1.0 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 13.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 1.7 MB/s eta 0:00:00
#   Building wheel for pyradiomics (pyproject.toml) ... done
#   Building wheel for docopt (setup.py) ... done

# %% [markdown]
# ## Shard cell  ← the ONLY thing you change per duplicated notebook
#
# Leave `NUM_SHARDS = 5`. Uncomment exactly one `SHARD_INDEX` line.

# %%
# --- Path to the folder where you pasted the three .py scripts ---
SCRIPT_DIR = '/content/drive/MyDrive/bsd/11_radiomics_for_gliomas/02_train/trial_80/notebooks'

# --- This notebook's shard. Uncomment exactly ONE line. ---
NUM_SHARDS = 5
SHARD_INDEX = 0
# SHARD_INDEX = 1
# SHARD_INDEX = 2
# SHARD_INDEX = 3
# SHARD_INDEX = 4

import os
NORMALIZE_SCRIPT = os.path.join(SCRIPT_DIR, '04_normalize_images.py')
EXTRACT_SCRIPT   = os.path.join(SCRIPT_DIR, '05_extract_wt_radiomics.py')
COMBINE_SCRIPT   = os.path.join(SCRIPT_DIR, '06_combine_features.py')

print(f"This notebook = shard {SHARD_INDEX} of {NUM_SHARDS}")
print(f"Scripts found:",
      os.path.exists(NORMALIZE_SCRIPT),
      os.path.exists(EXTRACT_SCRIPT),
      os.path.exists(COMBINE_SCRIPT))
# Out:
# This notebook = shard 0 of 5
# Scripts found: True True True

# %% [markdown]
# ## Smoke test (run ONCE, in a single notebook)
#
# No shard arguments = single-case test on BT0791. Normalizes that one case, then
# extracts it and prints the feature count. Confirms there is no GLCM hang before
# you commit all 5 machines.

# %%
# !python "{NORMALIZE_SCRIPT}"
# !python "{EXTRACT_SCRIPT}"
# Out:
# SMOKE TEST MODE: normalizing only BT0791
#
# Normalizing: BT0791
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Smoke test done.
# Fixed bin Count enabled! However, we recommend using a fixed bin Width. See http://pyradiomics.readthedocs.io/en/latest/faq.html#radiomics-fixed-bin-width for more details
# Extractor settings:
# {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binCount': 64}
#
# SMOKE TEST MODE: extracting only BT0791, nothing will be written.
#
# Extracting features for: BT0791
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> SMOKE TEST: 4224 features extracted (no hang).
#   -> sample keys: ['FLAIR_original_firstorder_10Percentile', 'FLAIR_original_firstorder_90Percentile', 'FLAIR_original_firstorder_Energy', 'FLAIR_original_firstorder_Entropy', 'FLAIR_original_firstorder_InterquartileRange']
#
# Smoke test done.

# %% [markdown]
# ## Step 1: Normalize (run in ALL 5 notebooks)
#
# Each notebook normalizes its own one-fifth of the cases. Wait for all 5 to finish
# before Step 2, because extraction reads the `_norm` files produced here.

# %%
# !python "{NORMALIZE_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Shard 0 of 5. Total case folders: 2061
#
# Normalizing: BT0001
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0008
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0018
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0024
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0033
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0042
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0055
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0063
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0075
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0083
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0090
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0101
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0108
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0120
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0128
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0137
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0142
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0147
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0155
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0160
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0169
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: already normalized, skipping.
#   -> t2: already normalized, skipping.
#
# Normalizing: BT0181
#   -> flair: already normalized, skipping.
#   -> t1ce: already normalized, skipping.
#   -> t1: brain mean 764.68, std 110.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 171.87, std 44.60 -> saved t2_norm.nii.gz
#
# Normalizing: BT0188
#   -> flair: brain mean 2154.68, std 486.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1930.84, std 443.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1850.49, std 470.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 924.51, std 263.87 -> saved t2_norm.nii.gz
#
# Normalizing: BT0194
#   -> flair: brain mean 11159.35, std 2580.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 13363.46, std 2664.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 10207.68, std 2209.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 6754.87, std 3204.79 -> saved t2_norm.nii.gz
#
# Normalizing: BT0205
#   -> flair: brain mean 269.98, std 92.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1239.64, std 214.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 355.41, std 139.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 619.78, std 269.68 -> saved t2_norm.nii.gz
#
# Normalizing: BT0213
#   -> flair: brain mean 424.35, std 111.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 646.22, std 170.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 584.99, std 169.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 683.13, std 260.21 -> saved t2_norm.nii.gz
#
# Normalizing: BT0222
#   -> flair: brain mean 329.29, std 74.70 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 625.89, std 94.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 485.58, std 81.34 -> saved t1_norm.nii.gz
#   -> t2: brain mean 388.66, std 95.20 -> saved t2_norm.nii.gz
#
# Normalizing: BT0227
#   -> flair: brain mean 237.45, std 58.30 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 428.08, std 71.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 687.08, std 114.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 332.62, std 136.99 -> saved t2_norm.nii.gz
#
# Normalizing: BT0236
#   -> flair: brain mean 1039.68, std 233.14 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2495.94, std 518.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2064.96, std 282.33 -> saved t1_norm.nii.gz
#   -> t2: brain mean 3097.08, std 839.46 -> saved t2_norm.nii.gz
#
# Normalizing: BT0244
#   -> flair: brain mean 361.39, std 96.57 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 757.23, std 92.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 590.27, std 188.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 595.79, std 282.50 -> saved t2_norm.nii.gz
#
# Normalizing: BT0252
#   -> flair: brain mean 277.34, std 56.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 613.37, std 110.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 657.63, std 139.49 -> saved t1_norm.nii.gz
#   -> t2: brain mean 397.66, std 115.75 -> saved t2_norm.nii.gz
#
# Normalizing: BT0262
#   -> flair: brain mean 311.42, std 51.24 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 698.50, std 95.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 679.99, std 103.12 -> saved t1_norm.nii.gz
#   -> t2: brain mean 904.52, std 240.98 -> saved t2_norm.nii.gz
#
# Normalizing: BT0275
#   -> flair: brain mean 234.72, std 48.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 816.60, std 111.30 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 799.51, std 119.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 644.96, std 216.29 -> saved t2_norm.nii.gz
#
# Normalizing: BT0282
#   -> flair: brain mean 16364.82, std 3422.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 35135.45, std 5159.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 33927.03, std 5806.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 8798.28, std 2363.75 -> saved t2_norm.nii.gz
#
# Normalizing: BT0289
#   -> flair: brain mean 333.51, std 69.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 468.00, std 68.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 455.16, std 68.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 351.53, std 100.47 -> saved t2_norm.nii.gz
#
# Normalizing: BT0296
#   -> flair: brain mean 261.77, std 77.14 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 435.72, std 87.67 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 378.46, std 73.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 369.37, std 154.44 -> saved t2_norm.nii.gz
#
# Normalizing: BT0306
#   -> flair: brain mean 71.22, std 18.03 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 489.10, std 75.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 439.36, std 80.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 159.78, std 48.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT0312
#   -> flair: brain mean 12861.35, std 3238.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 27256.30, std 4378.15 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 25392.76, std 4643.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 7331.94, std 2544.07 -> saved t2_norm.nii.gz
#
# Normalizing: BT0323
#   -> flair: brain mean 4398.21, std 981.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2805.63, std 511.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2909.67, std 622.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 7013.96, std 2394.26 -> saved t2_norm.nii.gz
#
# Normalizing: BT0333
#   -> flair: brain mean 9197.34, std 1964.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 17905.83, std 3166.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 17137.17, std 3692.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 17599.28, std 3979.17 -> saved t2_norm.nii.gz
#
# Normalizing: BT0345
#   -> flair: brain mean 399.20, std 83.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 324.94, std 71.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 612.98, std 92.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 367.66, std 154.40 -> saved t2_norm.nii.gz
#
# Normalizing: BT0359
#   -> flair: brain mean 1325.30, std 337.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3282.18, std 494.76 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3267.52, std 503.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2076.07, std 961.80 -> saved t2_norm.nii.gz
#
# Normalizing: BT0365
#   -> flair: brain mean 396.31, std 82.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 547.06, std 63.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 535.04, std 72.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 496.32, std 132.21 -> saved t2_norm.nii.gz
#
# Normalizing: BT0376
#   -> flair: brain mean 139.04, std 26.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 371.71, std 43.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 468.90, std 65.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 276.34, std 108.30 -> saved t2_norm.nii.gz
#
# Normalizing: BT0387
#   -> flair: brain mean 597.48, std 186.92 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1639.80, std 450.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1145.71, std 287.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 801.90, std 215.49 -> saved t2_norm.nii.gz
#
# Normalizing: BT0400
#   -> flair: brain mean 524.20, std 204.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1065.86, std 209.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 826.48, std 159.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 896.08, std 396.05 -> saved t2_norm.nii.gz
#
# Normalizing: BT0411
#   -> flair: brain mean 1167.07, std 307.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1909.45, std 365.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1804.62, std 317.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1843.82, std 656.17 -> saved t2_norm.nii.gz
#
# Normalizing: BT0422
#   -> flair: brain mean 762.41, std 221.64 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 771.52, std 142.53 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 698.53, std 127.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1093.97, std 253.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0431
#   -> flair: brain mean 552.10, std 132.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 949.09, std 120.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1272.42, std 189.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 717.66, std 282.30 -> saved t2_norm.nii.gz
#
# Normalizing: BT0448
#   -> flair: brain mean 616.41, std 256.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 920.46, std 158.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 945.30, std 157.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1136.39, std 574.34 -> saved t2_norm.nii.gz
#
# Normalizing: BT0461
#   -> flair: brain mean 238.89, std 75.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 478.36, std 79.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 513.61, std 93.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 341.32, std 136.97 -> saved t2_norm.nii.gz
#
# Normalizing: BT0468
#   -> flair: brain mean 451.34, std 82.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 531.44, std 112.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 605.73, std 93.14 -> saved t1_norm.nii.gz
#   -> t2: brain mean 380.70, std 151.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT0479
#   -> flair: brain mean 676.14, std 143.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1066.24, std 179.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1051.38, std 205.98 -> saved t1_norm.nii.gz
#   -> t2: brain mean 843.23, std 232.64 -> saved t2_norm.nii.gz
#
# Normalizing: BT0489
#   -> flair: brain mean 433.60, std 101.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 595.77, std 100.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 600.01, std 93.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 593.98, std 243.00 -> saved t2_norm.nii.gz
#
# Normalizing: BT0502
#   -> flair: brain mean 444.71, std 93.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 965.44, std 133.31 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 761.22, std 127.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 499.15, std 99.93 -> saved t2_norm.nii.gz
#
# Normalizing: BT0533
#   -> flair: brain mean 250.77, std 86.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 548.72, std 98.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 426.49, std 141.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 477.97, std 233.38 -> saved t2_norm.nii.gz
#
# Normalizing: BT0605
#   -> flair: brain mean 269.19, std 47.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 595.83, std 79.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 582.06, std 91.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 442.67, std 127.13 -> saved t2_norm.nii.gz
#
# Normalizing: BT0612
#   -> flair: brain mean 80224.31, std 18178.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 318838.69, std 60854.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 288425.62, std 66303.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 53364.68, std 12101.56 -> saved t2_norm.nii.gz
#
# Normalizing: BT0619
#   -> flair: brain mean 434.32, std 114.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 501.45, std 168.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 460.28, std 118.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 667.62, std 206.98 -> saved t2_norm.nii.gz
#
# Normalizing: BT0625
#   -> flair: brain mean 1459.93, std 517.11 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2815.64, std 752.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1320.46, std 205.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1413.70, std 620.81 -> saved t2_norm.nii.gz
#
# Normalizing: BT0632
#   -> flair: brain mean 35163.96, std 8226.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 402.25, std 86.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 435.25, std 83.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 97.60, std 35.77 -> saved t2_norm.nii.gz
#
# Normalizing: BT0638
#   -> flair: brain mean 375.27, std 97.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 860.51, std 155.52 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 853.50, std 145.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 805.01, std 342.73 -> saved t2_norm.nii.gz
#
# Normalizing: BT0646
#   -> flair: brain mean 321.41, std 105.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1058.39, std 192.96 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1155.83, std 213.06 -> saved t1_norm.nii.gz
#   -> t2: brain mean 492.36, std 240.73 -> saved t2_norm.nii.gz
#
# Normalizing: BT0655
#   -> flair: brain mean 411.61, std 120.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 575.63, std 133.03 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 637.63, std 143.85 -> saved t1_norm.nii.gz
#   -> t2: brain mean 570.53, std 349.48 -> saved t2_norm.nii.gz
#
# Normalizing: BT0663
#   -> flair: brain mean 1018.76, std 226.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2041.62, std 296.49 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1505.51, std 222.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1215.81, std 321.52 -> saved t2_norm.nii.gz
#
# Normalizing: BT0672
#   -> flair: brain mean 244.28, std 62.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 459.03, std 94.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 605.29, std 93.86 -> saved t1_norm.nii.gz
#   -> t2: brain mean 336.34, std 142.19 -> saved t2_norm.nii.gz
#
# Normalizing: BT0680
#   -> flair: brain mean 179.02, std 45.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 471.43, std 78.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 433.10, std 70.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 256.47, std 124.35 -> saved t2_norm.nii.gz
#
# Normalizing: BT0690
#   -> flair: brain mean 198.75, std 63.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 561.41, std 106.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 549.05, std 97.92 -> saved t1_norm.nii.gz
#   -> t2: brain mean 624.38, std 217.06 -> saved t2_norm.nii.gz
#
# Normalizing: BT0700
#   -> flair: brain mean 372.82, std 71.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 391.83, std 64.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 407.84, std 63.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 424.30, std 131.45 -> saved t2_norm.nii.gz
#
# Normalizing: BT0713
#   -> flair: brain mean 269.05, std 72.33 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 510.43, std 69.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 604.39, std 94.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 388.99, std 165.87 -> saved t2_norm.nii.gz
#
# Normalizing: BT0722
#   -> flair: brain mean 198.80, std 46.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 810.86, std 85.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 858.76, std 92.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 464.16, std 265.20 -> saved t2_norm.nii.gz
#
# Normalizing: BT0732
#   -> flair: brain mean 814.55, std 184.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1186.97, std 379.01 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 664.46, std 233.05 -> saved t1_norm.nii.gz
#   -> t2: brain mean 3033.43, std 725.43 -> saved t2_norm.nii.gz
#
# Normalizing: BT0738
#   -> flair: brain mean 4572.89, std 988.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 16957.74, std 5076.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 15373.96, std 4430.27 -> saved t1_norm.nii.gz
#   -> t2: brain mean 13409.09, std 4845.91 -> saved t2_norm.nii.gz
#
# Normalizing: BT0747
#   -> flair: brain mean 727.38, std 155.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2038.88, std 313.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1941.04, std 338.37 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1152.28, std 407.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT0752
#   -> flair: brain mean 147.03, std 33.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 448.13, std 68.48 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 450.75, std 71.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 289.75, std 87.18 -> saved t2_norm.nii.gz
#
# Normalizing: BT0759
#   -> flair: brain mean 331.79, std 77.93 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 377.37, std 115.64 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 370.45, std 88.01 -> saved t1_norm.nii.gz
#   -> t2: brain mean 303.38, std 158.05 -> saved t2_norm.nii.gz
#
# Normalizing: BT0767
#   -> flair: brain mean 460.12, std 115.84 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1155.96, std 393.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1323.06, std 202.05 -> saved t1_norm.nii.gz
#   -> t2: brain mean 734.16, std 251.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT0773
#   -> flair: brain mean 293.23, std 82.44 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1160.21, std 196.94 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 904.27, std 193.73 -> saved t1_norm.nii.gz
#   -> t2: brain mean 672.78, std 249.08 -> saved t2_norm.nii.gz
#
# Normalizing: BT0784
#   -> flair: brain mean 28354.06, std 6159.57 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 31479.21, std 5349.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 33495.63, std 6527.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 10611.22, std 4787.00 -> saved t2_norm.nii.gz
#
# Normalizing: BT0790
#   -> flair: brain mean 321.95, std 51.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 644.68, std 107.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 568.48, std 108.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 384.67, std 152.54 -> saved t2_norm.nii.gz
#
# Normalizing: BT0801
#   -> flair: brain mean 292.68, std 87.69 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1076.11, std 263.67 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 634.55, std 121.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 438.86, std 176.38 -> saved t2_norm.nii.gz
#
# Normalizing: BT0809
#   -> flair: brain mean 175.18, std 36.91 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 422.46, std 93.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 782.07, std 145.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 635.05, std 162.44 -> saved t2_norm.nii.gz
#
# Normalizing: BT0820
#   -> flair: brain mean 490.75, std 111.03 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 331.39, std 66.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 402.48, std 67.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 628.65, std 207.34 -> saved t2_norm.nii.gz
#
# Normalizing: BT0833
#   -> flair: brain mean 298.02, std 82.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 601.69, std 138.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 666.72, std 100.75 -> saved t1_norm.nii.gz
#   -> t2: brain mean 523.35, std 191.65 -> saved t2_norm.nii.gz
#
# Normalizing: BT0841
#   -> flair: brain mean 403.64, std 87.57 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 539.07, std 78.13 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 552.32, std 65.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 473.47, std 140.16 -> saved t2_norm.nii.gz
#
# Normalizing: BT0900
#   -> flair: brain mean 303.61, std 79.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 438.21, std 94.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 518.85, std 102.84 -> saved t1_norm.nii.gz
#   -> t2: brain mean 496.26, std 245.03 -> saved t2_norm.nii.gz
#
# Normalizing: BT0912
#   -> flair: brain mean 193.84, std 50.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 505.24, std 80.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 586.71, std 99.50 -> saved t1_norm.nii.gz
#   -> t2: brain mean 618.44, std 169.01 -> saved t2_norm.nii.gz
#
# Normalizing: BT0925
#   -> flair: brain mean 634.27, std 184.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1654.80, std 760.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1523.53, std 255.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1571.11, std 820.78 -> saved t2_norm.nii.gz
#
# Normalizing: BT0931
#   -> flair: brain mean 369.20, std 101.15 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 393.82, std 77.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 625.01, std 84.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 386.91, std 181.52 -> saved t2_norm.nii.gz
#
# Normalizing: BT0948
#   -> flair: brain mean 1399.25, std 417.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3947.90, std 1387.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1477.90, std 517.27 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2484.01, std 1536.16 -> saved t2_norm.nii.gz
#
# Normalizing: BT0957
#   -> flair: brain mean 185.53, std 45.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 461.22, std 59.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 479.92, std 64.74 -> saved t1_norm.nii.gz
#   -> t2: brain mean 155.08, std 119.20 -> saved t2_norm.nii.gz
#
# Normalizing: BT0962
#   -> flair: brain mean 1363.81, std 375.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1123.18, std 228.46 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1381.60, std 298.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 752.96, std 189.07 -> saved t2_norm.nii.gz
#
# Normalizing: BT0971
#   -> flair: brain mean 365.52, std 78.98 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 495.96, std 83.88 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 769.35, std 116.67 -> saved t1_norm.nii.gz
#   -> t2: brain mean 439.75, std 118.96 -> saved t2_norm.nii.gz
#
# Normalizing: BT1009
#   -> flair: brain mean 330.04, std 89.45 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 484.08, std 114.90 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 405.73, std 73.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 496.19, std 169.32 -> saved t2_norm.nii.gz
#
# Normalizing: BT1016
#   -> flair: brain mean 248.73, std 52.31 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 595.15, std 91.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 544.00, std 90.07 -> saved t1_norm.nii.gz
#   -> t2: brain mean 387.00, std 130.76 -> saved t2_norm.nii.gz
#
# Normalizing: BT1021
#   -> flair: brain mean 271.00, std 73.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 549.24, std 89.56 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 571.17, std 98.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 323.71, std 144.71 -> saved t2_norm.nii.gz
#
# Normalizing: BT1028
#   -> flair: brain mean 263.91, std 74.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 338.37, std 75.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 339.65, std 94.26 -> saved t1_norm.nii.gz
#   -> t2: brain mean 450.32, std 124.26 -> saved t2_norm.nii.gz
#
# Normalizing: BT1035
#   -> flair: brain mean 175.01, std 48.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 435.01, std 88.86 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 334.47, std 81.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 432.15, std 186.96 -> saved t2_norm.nii.gz
#
# Normalizing: BT1041
#   -> flair: brain mean 253.76, std 75.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 623.45, std 109.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 707.59, std 122.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 504.24, std 325.89 -> saved t2_norm.nii.gz
#
# Normalizing: BT1051
#   -> flair: brain mean 340.00, std 78.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 901.26, std 133.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 843.76, std 145.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 488.06, std 157.84 -> saved t2_norm.nii.gz
#
# Normalizing: BT1060
#   -> flair: brain mean 238.48, std 60.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 432.22, std 151.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 454.55, std 108.61 -> saved t1_norm.nii.gz
#   -> t2: brain mean 364.24, std 171.59 -> saved t2_norm.nii.gz
#
# Normalizing: BT1072
#   -> flair: brain mean 339.02, std 85.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 509.16, std 93.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 799.62, std 138.18 -> saved t1_norm.nii.gz
#   -> t2: brain mean 483.37, std 176.46 -> saved t2_norm.nii.gz
#
# Normalizing: BT1081
#   -> flair: brain mean 490.42, std 99.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 865.42, std 234.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 615.46, std 122.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 469.64, std 194.53 -> saved t2_norm.nii.gz
#
# Normalizing: BT1086
#   -> flair: brain mean 755.66, std 155.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2193.85, std 333.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1914.56, std 345.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1488.59, std 404.79 -> saved t2_norm.nii.gz
#
# Normalizing: BT1092
#   -> flair: brain mean 1227.85, std 357.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1561.27, std 525.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1482.52, std 521.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 806.98, std 252.36 -> saved t2_norm.nii.gz
#
# Normalizing: BT1099
#   -> flair: brain mean 1255.06, std 254.54 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2175.79, std 613.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1871.38, std 581.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2510.66, std 973.57 -> saved t2_norm.nii.gz
#
# Normalizing: BT1105
#   -> flair: brain mean 601.62, std 172.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 837.47, std 251.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1338.29, std 439.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1545.59, std 721.18 -> saved t2_norm.nii.gz
#
# Normalizing: BT1110
#   -> flair: brain mean 510.96, std 112.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 438.23, std 71.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 460.75, std 76.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 357.30, std 117.55 -> saved t2_norm.nii.gz
#
# Normalizing: BT1116
#   -> flair: brain mean 261.35, std 90.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 631.34, std 220.92 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 565.97, std 192.82 -> saved t1_norm.nii.gz
#   -> t2: brain mean 701.69, std 259.67 -> saved t2_norm.nii.gz
#
# Normalizing: BT1123
#   -> flair: brain mean 1245.12, std 363.51 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 822.60, std 196.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 879.95, std 205.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 820.32, std 241.58 -> saved t2_norm.nii.gz
#
# Normalizing: BT1129
#   -> flair: brain mean 379.42, std 81.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 339.60, std 59.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 608.99, std 90.77 -> saved t1_norm.nii.gz
#   -> t2: brain mean 399.77, std 162.04 -> saved t2_norm.nii.gz
#
# Normalizing: BT1138
#   -> flair: brain mean 177.79, std 42.60 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 542.87, std 87.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 489.55, std 86.45 -> saved t1_norm.nii.gz
#   -> t2: brain mean 491.21, std 173.34 -> saved t2_norm.nii.gz
#
# Normalizing: BT1146
#   -> flair: brain mean 1486.84, std 485.46 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 686.48, std 225.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 916.81, std 324.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 780.39, std 432.69 -> saved t2_norm.nii.gz
#
# Normalizing: BT1201
#   -> flair: brain mean 1307.80, std 249.51 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 813.36, std 155.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1072.09, std 198.31 -> saved t1_norm.nii.gz
#   -> t2: brain mean 782.52, std 157.31 -> saved t2_norm.nii.gz
#
# Normalizing: BT1213
#   -> flair: brain mean 396.27, std 89.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 620.45, std 124.16 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 657.66, std 165.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 504.17, std 144.89 -> saved t2_norm.nii.gz
#
# Normalizing: BT1228
#   -> flair: brain mean 743.90, std 172.59 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 704.70, std 168.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 700.61, std 193.22 -> saved t1_norm.nii.gz
#   -> t2: brain mean 796.99, std 189.49 -> saved t2_norm.nii.gz
#
# Normalizing: BT1235
#   -> flair: brain mean 347.11, std 100.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 596.74, std 96.08 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 639.97, std 107.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 501.12, std 167.83 -> saved t2_norm.nii.gz
#
# Normalizing: BT1244
#   -> flair: brain mean 565.74, std 126.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 771.45, std 132.40 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 690.65, std 178.40 -> saved t1_norm.nii.gz
#   -> t2: brain mean 752.69, std 445.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT1250
#   -> flair: brain mean 295.77, std 80.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 618.64, std 105.12 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 700.58, std 109.09 -> saved t1_norm.nii.gz
#   -> t2: brain mean 441.73, std 181.65 -> saved t2_norm.nii.gz
#
# Normalizing: BT1259
#   -> flair: brain mean 1454.06, std 340.62 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1027.36, std 181.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1231.03, std 213.41 -> saved t1_norm.nii.gz
#   -> t2: brain mean 731.33, std 210.14 -> saved t2_norm.nii.gz
#
# Normalizing: BT1269
#   -> flair: brain mean 696.67, std 172.97 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 677.54, std 183.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1029.77, std 152.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 828.95, std 316.72 -> saved t2_norm.nii.gz
#
# Normalizing: BT1274
#   -> flair: brain mean 499.77, std 110.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1212.22, std 169.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1220.22, std 205.59 -> saved t1_norm.nii.gz
#   -> t2: brain mean 818.87, std 287.42 -> saved t2_norm.nii.gz
#
# Normalizing: BT1282
#   -> flair: brain mean 532.91, std 102.58 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 750.76, std 129.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 674.45, std 118.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 926.47, std 332.85 -> saved t2_norm.nii.gz
#
# Normalizing: BT1288
#   -> flair: brain mean 965.38, std 205.70 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2225.23, std 295.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2274.42, std 336.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1298.90, std 434.89 -> saved t2_norm.nii.gz
#
# Normalizing: BT1300
#   -> flair: brain mean 352.98, std 102.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1302.31, std 199.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1407.64, std 221.40 -> saved t1_norm.nii.gz
#   -> t2: brain mean 746.94, std 364.05 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0001
#   -> flair: brain mean 305.35, std 66.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 309.74, std 94.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 394.09, std 72.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 434.04, std 133.06 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0006
#   -> flair: brain mean 296.48, std 85.32 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 356.35, std 86.65 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 417.89, std 67.90 -> saved t1_norm.nii.gz
#   -> t2: brain mean 397.36, std 167.60 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0011
#   -> flair: brain mean 236.31, std 81.93 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 481.29, std 120.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 232.74, std 63.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 356.30, std 158.73 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0016
#   -> flair: brain mean 211.37, std 75.10 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 104.47, std 23.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 324.84, std 68.82 -> saved t1_norm.nii.gz
#   -> t2: brain mean 365.92, std 154.18 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0021
#   -> flair: brain mean 157.22, std 43.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 179.25, std 34.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 162.00, std 36.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 187.06, std 52.71 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0026
#   -> flair: brain mean 305.65, std 96.94 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 356.05, std 72.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 320.82, std 65.05 -> saved t1_norm.nii.gz
#   -> t2: brain mean 394.75, std 139.72 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0031
#   -> flair: brain mean 1149.45, std 449.29 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1533.14, std 559.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1840.53, std 299.07 -> saved t1_norm.nii.gz
#   -> t2: brain mean 773.84, std 392.96 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0036
#   -> flair: brain mean 331.65, std 109.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 508.06, std 133.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 474.45, std 123.66 -> saved t1_norm.nii.gz
#   -> t2: brain mean 650.29, std 246.46 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0041
#   -> flair: brain mean 478.18, std 191.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 377.26, std 103.81 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 284.55, std 82.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 683.67, std 218.59 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0046
#   -> flair: brain mean 708.93, std 238.85 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 568.73, std 181.89 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 783.90, std 249.27 -> saved t1_norm.nii.gz
#   -> t2: brain mean 635.24, std 413.46 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0051
#   -> flair: brain mean 231.91, std 74.88 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 716.96, std 131.23 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 593.16, std 115.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 394.34, std 128.87 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0056
#   -> flair: brain mean 924.77, std 338.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1070.68, std 485.89 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1021.34, std 182.45 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1866.59, std 944.52 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0061
#   -> flair: brain mean 137.41, std 33.28 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 83.99, std 37.22 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 235.38, std 41.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 247.18, std 74.34 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0066
#   -> flair: brain mean 408.01, std 120.59 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 507.62, std 106.46 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 437.86, std 108.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 651.21, std 201.11 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0071
#   -> flair: brain mean 147.63, std 35.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 110.07, std 32.56 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 110.06, std 33.76 -> saved t1_norm.nii.gz
#   -> t2: brain mean 185.91, std 51.32 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0076
#   -> flair: brain mean 240.42, std 81.79 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 154.60, std 52.33 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 315.46, std 77.41 -> saved t1_norm.nii.gz
#   -> t2: brain mean 438.60, std 146.04 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0081
#   -> flair: brain mean 284.89, std 78.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 342.19, std 76.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 359.43, std 66.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 319.83, std 137.90 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0086
#   -> flair: brain mean 1543.69, std 499.05 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4905.48, std 1535.83 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1827.90, std 331.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1738.36, std 1288.29 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0091
#   -> flair: brain mean 869.79, std 266.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 793.41, std 181.50 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 816.12, std 183.08 -> saved t1_norm.nii.gz
#   -> t2: brain mean 382.82, std 176.63 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0096
#   -> flair: brain mean 887.31, std 250.47 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1057.42, std 233.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 901.39, std 208.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 406.23, std 245.62 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0101
#   -> flair: brain mean 385.45, std 120.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 514.16, std 141.51 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 496.92, std 137.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 558.45, std 197.88 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0106
#   -> flair: brain mean 1384.16, std 453.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2418.14, std 945.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2055.80, std 685.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1209.82, std 718.52 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0111
#   -> flair: brain mean 413.75, std 109.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 498.15, std 102.37 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 421.66, std 72.98 -> saved t1_norm.nii.gz
#   -> t2: brain mean 369.36, std 63.40 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0116
#   -> flair: brain mean 490.02, std 194.33 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 863.42, std 172.18 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 770.13, std 166.03 -> saved t1_norm.nii.gz
#   -> t2: brain mean 698.77, std 331.58 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0121
#   -> flair: brain mean 312.27, std 73.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 537.26, std 110.34 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 466.20, std 98.25 -> saved t1_norm.nii.gz
#   -> t2: brain mean 445.14, std 138.90 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0126
#   -> flair: brain mean 313.77, std 112.48 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 438.77, std 109.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 345.86, std 79.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 489.19, std 186.42 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0131
#   -> flair: brain mean 786.60, std 203.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 759.26, std 218.07 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 633.51, std 152.09 -> saved t1_norm.nii.gz
#   -> t2: brain mean 843.83, std 319.35 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0136
#   -> flair: brain mean 516.28, std 188.20 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1096.92, std 442.38 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 797.35, std 160.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 555.81, std 336.20 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0141
#   -> flair: brain mean 443.99, std 142.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 531.19, std 117.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 505.36, std 109.17 -> saved t1_norm.nii.gz
#   -> t2: brain mean 676.02, std 247.32 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0146
#   -> flair: brain mean 839.19, std 239.78 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3064.07, std 1444.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1275.04, std 272.02 -> saved t1_norm.nii.gz
#   -> t2: brain mean 2012.50, std 601.56 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0151
#   -> flair: brain mean 274.41, std 78.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 324.98, std 90.06 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 286.01, std 59.48 -> saved t1_norm.nii.gz
#   -> t2: brain mean 379.75, std 144.32 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0156
#   -> flair: brain mean 246.33, std 83.76 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 373.26, std 82.85 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 361.73, std 83.97 -> saved t1_norm.nii.gz
#   -> t2: brain mean 321.06, std 136.31 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0161
#   -> flair: brain mean 798.65, std 164.37 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 911.95, std 198.73 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1007.75, std 164.48 -> saved t1_norm.nii.gz
#   -> t2: brain mean 354.89, std 164.84 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0166
#   -> flair: brain mean 820.58, std 228.73 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 764.92, std 231.25 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 688.05, std 180.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 437.94, std 220.53 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0171
#   -> flair: brain mean 765.75, std 247.74 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 691.93, std 199.57 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 565.42, std 126.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 432.46, std 197.32 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0176
#   -> flair: brain mean 385.00, std 102.14 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 223.40, std 56.28 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 256.08, std 83.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 538.78, std 294.00 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0181
#   -> flair: brain mean 997.62, std 307.25 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 828.48, std 300.68 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 778.81, std 320.71 -> saved t1_norm.nii.gz
#   -> t2: brain mean 755.18, std 240.42 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0186
#   -> flair: brain mean 1171.62, std 473.09 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 694.53, std 252.58 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 712.54, std 265.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 859.97, std 360.29 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0191
#   -> flair: brain mean 348.32, std 78.03 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 404.71, std 77.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 391.82, std 74.37 -> saved t1_norm.nii.gz
#   -> t2: brain mean 470.79, std 100.11 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0196
#   -> flair: brain mean 354.47, std 135.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 323.20, std 82.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 290.84, std 85.76 -> saved t1_norm.nii.gz
#   -> t2: brain mean 547.98, std 196.24 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0201
#   -> flair: brain mean 311.02, std 104.01 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 400.75, std 109.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 302.72, std 70.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 448.67, std 185.95 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0206
#   -> flair: brain mean 981.92, std 325.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2123.97, std 654.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1365.55, std 208.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1051.91, std 514.59 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0211
#   -> flair: brain mean 881.86, std 314.37 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4512.96, std 1111.10 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2887.21, std 456.24 -> saved t1_norm.nii.gz
#   -> t2: brain mean 1691.18, std 744.29 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0216
#   -> flair: brain mean 383.44, std 162.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 572.42, std 138.45 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 563.16, std 129.80 -> saved t1_norm.nii.gz
#   -> t2: brain mean 674.81, std 396.42 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0221
#   -> flair: brain mean 412.66, std 96.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1337.90, std 216.17 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 555.08, std 106.83 -> saved t1_norm.nii.gz
#   -> t2: brain mean 372.64, std 68.28 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0226
#   -> flair: brain mean 634.06, std 222.27 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 645.37, std 224.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 801.22, std 300.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 871.93, std 356.35 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0231
#   -> flair: brain mean 113.54, std 50.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 94.18, std 27.66 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 283.73, std 56.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 193.76, std 99.58 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0236
#   -> flair: brain mean 276.18, std 76.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 411.39, std 116.53 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 852.49, std 206.58 -> saved t1_norm.nii.gz
#   -> t2: brain mean 406.42, std 102.51 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0241
#   -> flair: brain mean 685.23, std 223.37 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 593.50, std 130.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 636.22, std 152.49 -> saved t1_norm.nii.gz
#   -> t2: brain mean 948.95, std 315.78 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0246
#   -> flair: brain mean 252.82, std 94.55 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 389.42, std 106.39 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 357.80, std 96.42 -> saved t1_norm.nii.gz
#   -> t2: brain mean 491.01, std 212.80 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0251
#   -> flair: brain mean 102.93, std 29.68 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 95.50, std 31.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 283.85, std 68.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 195.06, std 79.21 -> saved t2_norm.nii.gz
#
# Normalizing: MR_EGD-0256
# ...
#
# Normalizing: UCSF-PDGM-0270_nifti
#   -> flair: brain mean 765.09, std 263.86 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6594.25, std 1569.05 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1781.58, std 281.15 -> saved t1_norm.nii.gz
#   -> t2: brain mean 394.12, std 202.00 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0276_nifti
#   -> flair: brain mean 976.23, std 371.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4036.41, std 1071.74 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3632.39, std 842.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 510.50, std 213.46 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0282_nifti
#   -> flair: brain mean 1097.80, std 408.66 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3233.85, std 944.52 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2929.49, std 820.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 625.75, std 317.60 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0287_nifti
#   -> flair: brain mean 918.48, std 306.35 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3392.56, std 954.26 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2871.86, std 812.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 411.63, std 189.30 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0296_nifti
#   -> flair: brain mean 945.06, std 358.43 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3863.29, std 1237.77 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2749.07, std 874.95 -> saved t1_norm.nii.gz
#   -> t2: brain mean 757.29, std 397.51 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0303_nifti
#   -> flair: brain mean 611.03, std 250.18 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5913.01, std 1357.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 796.66, std 155.37 -> saved t1_norm.nii.gz
#   -> t2: brain mean 361.21, std 221.99 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0308_nifti
#   -> flair: brain mean 1477.99, std 511.11 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3776.60, std 1029.70 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3271.08, std 802.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 524.64, std 196.42 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0313_nifti
#   -> flair: brain mean 1199.16, std 414.63 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3502.44, std 1231.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2591.78, std 815.46 -> saved t1_norm.nii.gz
#   -> t2: brain mean 580.55, std 276.98 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0319_nifti
#   -> flair: brain mean 1050.45, std 404.61 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3096.52, std 1113.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2077.61, std 556.36 -> saved t1_norm.nii.gz
#   -> t2: brain mean 686.72, std 374.87 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0325_nifti
#   -> flair: brain mean 1060.51, std 418.16 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3906.00, std 1343.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2633.37, std 861.92 -> saved t1_norm.nii.gz
#   -> t2: brain mean 520.82, std 293.06 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0330_nifti
#   -> flair: brain mean 1100.16, std 443.36 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2469.74, std 1098.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1363.01, std 241.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 686.07, std 382.73 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0335_nifti
#   -> flair: brain mean 956.16, std 323.65 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2038.70, std 818.09 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1303.02, std 249.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 639.00, std 357.72 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0340_nifti
#   -> flair: brain mean 424.86, std 144.56 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2214.23, std 543.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1318.31, std 256.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 268.20, std 222.45 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0345_nifti
#   -> flair: brain mean 1239.28, std 388.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6928.04, std 1843.89 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2473.62, std 458.82 -> saved t1_norm.nii.gz
#   -> t2: brain mean 902.53, std 483.67 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0350_nifti
#   -> flair: brain mean 914.96, std 297.02 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4998.99, std 1679.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4131.75, std 1129.69 -> saved t1_norm.nii.gz
#   -> t2: brain mean 507.97, std 233.11 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0355_nifti
#   -> flair: brain mean 951.61, std 360.13 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2891.60, std 864.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2717.76, std 637.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 750.46, std 358.21 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0360_nifti
#   -> flair: brain mean 898.35, std 307.35 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3659.41, std 1015.27 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2990.39, std 837.63 -> saved t1_norm.nii.gz
#   -> t2: brain mean 796.49, std 417.59 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0365_nifti
#   -> flair: brain mean 512.20, std 168.90 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6352.71, std 1447.56 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1436.60, std 302.65 -> saved t1_norm.nii.gz
#   -> t2: brain mean 390.10, std 229.55 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0370_nifti
#   -> flair: brain mean 1124.12, std 375.72 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3346.89, std 972.71 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2355.76, std 790.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 738.02, std 410.68 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0375_nifti
#   -> flair: brain mean 1677.46, std 587.53 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6303.67, std 1829.47 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3561.71, std 1156.39 -> saved t1_norm.nii.gz
#   -> t2: brain mean 922.01, std 458.32 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0380_nifti
#   -> flair: brain mean 895.58, std 296.35 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4766.14, std 1237.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3389.17, std 835.55 -> saved t1_norm.nii.gz
#   -> t2: brain mean 557.91, std 239.77 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0385_nifti
#   -> flair: brain mean 916.95, std 322.82 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4695.80, std 1522.61 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1097.48, std 201.29 -> saved t1_norm.nii.gz
#   -> t2: brain mean 618.45, std 298.24 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0390_nifti
#   -> flair: brain mean 1314.79, std 507.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4089.96, std 1338.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2095.11, std 322.23 -> saved t1_norm.nii.gz
#   -> t2: brain mean 849.13, std 420.62 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0395_nifti
#   -> flair: brain mean 883.76, std 330.96 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2955.49, std 829.94 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2762.80, std 776.72 -> saved t1_norm.nii.gz
#   -> t2: brain mean 550.11, std 357.08 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0400_nifti
#   -> flair: brain mean 969.09, std 341.71 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6433.84, std 1533.79 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4899.86, std 1114.10 -> saved t1_norm.nii.gz
#   -> t2: brain mean 456.77, std 229.81 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0405_nifti
#   -> flair: brain mean 1042.67, std 342.00 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3270.72, std 857.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2922.55, std 751.64 -> saved t1_norm.nii.gz
#   -> t2: brain mean 485.19, std 190.40 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0411_nifti
#   -> flair: brain mean 1183.24, std 482.22 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4029.79, std 1256.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2935.72, std 766.43 -> saved t1_norm.nii.gz
#   -> t2: brain mean 623.60, std 301.53 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0416_nifti
#   -> flair: brain mean 723.06, std 257.27 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3897.82, std 1174.24 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3951.84, std 1037.19 -> saved t1_norm.nii.gz
#   -> t2: brain mean 630.97, std 303.29 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0421_nifti
#   -> flair: brain mean 1002.23, std 387.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2032.56, std 794.32 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1892.40, std 630.52 -> saved t1_norm.nii.gz
#   -> t2: brain mean 719.38, std 402.65 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0426_nifti
#   -> flair: brain mean 778.24, std 295.23 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2865.46, std 1330.43 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1143.30, std 162.89 -> saved t1_norm.nii.gz
#   -> t2: brain mean 557.09, std 284.09 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0431_nifti
#   -> flair: brain mean 858.56, std 312.49 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5511.54, std 1451.21 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 4877.27, std 1140.32 -> saved t1_norm.nii.gz
#   -> t2: brain mean 609.41, std 280.98 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0436_nifti
#   -> flair: brain mean 1131.16, std 393.87 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4362.86, std 1346.59 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3643.42, std 974.30 -> saved t1_norm.nii.gz
#   -> t2: brain mean 541.14, std 261.12 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0441_nifti
#   -> flair: brain mean 863.96, std 316.48 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2600.72, std 965.62 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2212.54, std 754.04 -> saved t1_norm.nii.gz
#   -> t2: brain mean 747.81, std 303.32 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0446_nifti
#   -> flair: brain mean 1047.87, std 354.75 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3625.20, std 1316.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3106.42, std 826.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 528.19, std 232.41 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0451_nifti
#   -> flair: brain mean 898.06, std 289.81 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3940.91, std 1097.84 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2912.52, std 776.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 487.64, std 189.36 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0456_nifti
#   -> flair: brain mean 926.90, std 302.51 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 5040.59, std 1567.95 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3620.39, std 1142.60 -> saved t1_norm.nii.gz
#   -> t2: brain mean 610.85, std 324.83 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0461_nifti
#   -> flair: brain mean 1106.08, std 411.50 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3391.52, std 1006.42 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2664.18, std 714.96 -> saved t1_norm.nii.gz
#   -> t2: brain mean 754.57, std 350.56 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0466_nifti
#   -> flair: brain mean 1176.15, std 361.89 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2465.39, std 864.69 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1431.55, std 208.00 -> saved t1_norm.nii.gz
#   -> t2: brain mean 645.82, std 307.49 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0471_nifti
#   -> flair: brain mean 309.76, std 102.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1902.78, std 411.91 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1885.15, std 432.53 -> saved t1_norm.nii.gz
#   -> t2: brain mean 131.86, std 83.64 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0476_nifti
#   -> flair: brain mean 1067.38, std 333.40 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2241.85, std 820.78 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1197.01, std 235.85 -> saved t1_norm.nii.gz
#   -> t2: brain mean 581.80, std 308.02 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0481_nifti
#   -> flair: brain mean 980.63, std 311.83 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4024.42, std 1039.63 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3337.92, std 782.57 -> saved t1_norm.nii.gz
#   -> t2: brain mean 720.03, std 297.97 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0486_nifti
#   -> flair: brain mean 1313.54, std 389.42 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3997.50, std 1125.54 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1580.59, std 291.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 614.68, std 342.09 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0491_nifti
#   -> flair: brain mean 1014.12, std 364.34 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4483.73, std 1311.98 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3916.65, std 1106.49 -> saved t1_norm.nii.gz
#   -> t2: brain mean 418.85, std 202.87 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0496_nifti
#   -> flair: brain mean 1059.94, std 330.99 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3467.16, std 1167.11 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2745.19, std 839.67 -> saved t1_norm.nii.gz
#   -> t2: brain mean 884.78, std 411.59 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0501_nifti
#   -> flair: brain mean 1597.04, std 593.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2722.81, std 824.19 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2664.50, std 696.68 -> saved t1_norm.nii.gz
#   -> t2: brain mean 677.73, std 345.23 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0506_nifti
#   -> flair: brain mean 521.27, std 174.69 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 1534.84, std 441.14 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1349.09, std 361.16 -> saved t1_norm.nii.gz
#   -> t2: brain mean 257.05, std 155.18 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0511_nifti
#   -> flair: brain mean 1065.62, std 363.17 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4348.43, std 1299.35 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3511.85, std 1034.38 -> saved t1_norm.nii.gz
#   -> t2: brain mean 603.04, std 320.36 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0516_nifti
#   -> flair: brain mean 1011.30, std 349.52 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 4071.88, std 1270.20 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3121.79, std 941.54 -> saved t1_norm.nii.gz
#   -> t2: brain mean 770.06, std 353.29 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0521_nifti
#   -> flair: brain mean 962.19, std 318.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2515.72, std 776.99 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 1990.63, std 619.44 -> saved t1_norm.nii.gz
#   -> t2: brain mean 500.88, std 346.22 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0526_nifti
#   -> flair: brain mean 950.91, std 351.07 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3425.56, std 1113.36 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2619.59, std 822.88 -> saved t1_norm.nii.gz
#   -> t2: brain mean 875.82, std 447.33 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0531_nifti
#   -> flair: brain mean 1190.02, std 548.54 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 2809.46, std 1005.80 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 2528.71, std 811.41 -> saved t1_norm.nii.gz
#   -> t2: brain mean 831.59, std 466.60 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0536_nifti
#   -> flair: brain mean 1129.02, std 350.39 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 6051.90, std 1623.72 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 5197.86, std 1185.78 -> saved t1_norm.nii.gz
#   -> t2: brain mean 341.80, std 133.83 -> saved t2_norm.nii.gz
#
# Normalizing: UCSF-PDGM-0541_nifti
#   -> flair: brain mean 945.26, std 331.06 -> saved flair_norm.nii.gz
#   -> t1ce: brain mean 3649.67, std 1116.97 -> saved t1ce_norm.nii.gz
#   -> t1: brain mean 3115.54, std 808.47 -> saved t1_norm.nii.gz
#   -> t2: brain mean 599.66, std 266.79 -> saved t2_norm.nii.gz
#
# Shard 0 of 5 complete.

# %% [markdown]
# ## Step 2: Extract (run in ALL 5 notebooks, after Step 1 is fully done)
#
# Each notebook extracts its own one-fifth and writes one CSV per case into
# `features/per_case/`. Safe to run concurrently (no shared file).

# %%
# !python "{EXTRACT_SCRIPT}" {NUM_SHARDS} {SHARD_INDEX}
# Out:
# Streaming output truncated to the last 5000 lines.
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote TCGA-HT-A61A.csv
# Extracting features for: UCSF-PDGM-0009_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0009_nifti.csv
# Extracting features for: UCSF-PDGM-0014_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0014_nifti.csv
# Extracting features for: UCSF-PDGM-0019_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0019_nifti.csv
# Extracting features for: UCSF-PDGM-0024_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0024_nifti.csv
# Extracting features for: UCSF-PDGM-0030_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0030_nifti.csv
# Extracting features for: UCSF-PDGM-0035_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0035_nifti.csv
# Extracting features for: UCSF-PDGM-0040_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0040_nifti.csv
# Extracting features for: UCSF-PDGM-0045_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0045_nifti.csv
# Extracting features for: UCSF-PDGM-0050_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0050_nifti.csv
# Extracting features for: UCSF-PDGM-0058_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0526_nifti.csv
# Extracting features for: UCSF-PDGM-0531_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0531_nifti.csv
# Extracting features for: UCSF-PDGM-0536_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0536_nifti.csv
# Extracting features for: UCSF-PDGM-0541_nifti
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   -> wrote UCSF-PDGM-0541_nifti.csv
#
# Shard 0 of 5 complete.

# %% [markdown]
# ## Step 3: Combine (run ONCE, in a single notebook, after all of Step 2 is done)
#
# Concatenates every per-case CSV into `all_radiomics_features.csv` and prints
# per-cohort counts plus any cases missing a sequence.

# %%
# !python "{COMBINE_SCRIPT}"
# Out:
# Found 2058 per-case files.
#
# Combined table: 2058 rows, 4226 columns.
# Saved to: /content/drive/MyDrive/bsd/11_radiomics_for_gliomas/02_train/trial_80/features/all_radiomics_features.csv
#
# Cases per cohort:
#   EGD: 774
#   UTSW: 622
#   UCSF: 495
#   TCGA: 167
#
# Rows with at least one fully-missing sequence (NaN-filled):
#   FLAIR: 1 cases
#   T1CE: 1 cases
#   T1: 1 cases
#   T2: 1 cases
